# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra-FallahMMA/DRL_Offload_Allocation/blob/main/Random_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import Libraries

# %%
import xml.etree.ElementTree as ET
from io import StringIO
import os
import re
import numpy as np
from collections import deque, defaultdict
import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.models import load_model
from itertools import product
import tensorflow as tf
# !pip install simpy
import simpy

# Set TensorFlow logging level to suppress detailed logs
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %% [markdown]
# # class RandomAgent

# %%
class RandomAgent:

  def __init__(self, action_size):
      self.action_size = action_size

  def choose_action(self):
        return random.randrange(self.action_size)

# %% [markdown]
# # class Task

# %%
class Task:
    def __init__(self, id, instructions, workflow_id):
        self.id = id
        self.instructions = instructions  # Execution time or computational instructions
        self.children = []  # List of tasks that depend on this task
        self.parents = []  # List of tasks this task depends on
        self.executed = False  # Status of execution
        self.executed_on = None  # Node this task was executed on
        self.execution_time = 0  # Time taken to execute the task
        self.cost = 0  # Cost of executing the task
        self.comm_delay = 0  # Communication delay in seconds
        self.workflow_id = workflow_id  # Workflow identifier to which this task belongs

# %% [markdown]
# # class Workflow

# %%
class Workflow:
    def __init__(self, id):
        self.id = id  # Workflow identifier
        self.tasks = {}  # Dictionary of tasks in the workflow

    def add_task(self, task_id, instructions, parent_ids=[]):
        if task_id not in self.tasks:
            self.tasks[task_id] = Task(task_id, instructions, self.id)
        task = self.tasks[task_id]
        for parent_id in parent_ids:
            if parent_id not in self.tasks:
                self.tasks[parent_id] = Task(parent_id, 0, self.id)
            parent_task = self.tasks[parent_id]
            parent_task.children.append(task)
            task.parents.append(parent_task)

# %% [markdown]
# # class parse_dax

# %%
def parse_dax(file_path, workflow_id):
    tree = ET.parse(file_path)
    root = tree.getroot()

    workflow_id = workflow_id
    workflow = Workflow(workflow_id)

    # Parse jobs
    jobs = {job.attrib['id']: job for job in root.findall('{http://pegasus.isi.edu/schema/DAX}job')}

    # Add jobs to workflow
    for job_id, job in jobs.items():
        instructions = float(job.attrib.get('runtime', 0))
        workflow.add_task(job_id, instructions)

    # Parse dependencies
    for child in root.findall('{http://pegasus.isi.edu/schema/DAX}child'):
        child_id = child.attrib['ref']
        parent_ids = [parent.attrib['ref'] for parent in child.findall('{http://pegasus.isi.edu/schema/DAX}parent')]
        workflow.add_task(child_id, 0, parent_ids)  # Adds a child node with its parent nodes, setting instructions to 0 to avoid overwrite

    return workflow


def ensemble_of_workflows(name, size=10, distribution='constant', dax_path=''):
    ws = []
    ensemble = []
    directory_path = dax_path  # Directory containing DAX files

    # List and filter files in directory
    files = os.listdir(directory_path)
    filtered_files = [file for file in files if name in file]

    if distribution == 'constant':
        pattern = r'100(?!\d)'
        for s in filtered_files:
            if re.search(pattern, s):
                ensemble = [s] * size  # Replicate the matched file 'size' times
                break
    else:
        numbers = np.random.randint(0, len(filtered_files), size)
        ensemble = [filtered_files[i] for i in numbers]  # Select random files based on uniform distribution
    w_id = 0
    for name in ensemble:
        ws.append(parse_dax(dax_path+name,w_id))
        w_id = w_id + 1

    return ws

# %% [markdown]
# # Loading dax_file

# %%
from google.colab import drive
import glob

drive.mount('/content/drive')
folder_path = '/content/drive/My Drive/Zahra/dax/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # class Device

# %%
class Device:
    def __init__(self, id, mips, cost_per_hour, env):
        self.id = id
        self.mips = mips
        self.cost_per_hour = cost_per_hour
        self.queue = deque()
        self.runnig_queue = deque()
        self.resource = simpy.Resource(env, capacity=1)

    def add_task_to_queue(self, task):
        self.queue.append(task)

    def get_next_task(self):
        return self.queue.popleft() if self.queue else None

    def waiting_time(self):
        waiting_time = 0
        for t in self.queue:
            waiting_time += t.instructions / self.mips
        return waiting_time

# %% [markdown]
# # class FogEnv

# %%
import simpy

class FogEnv:
    def __init__(self, env, iot_devices, fog_nodes, cloud_servers, workflows):
        self.env = env
        self.iot_devices = iot_devices
        self.fog_nodes = fog_nodes
        self.cloud_servers = cloud_servers
        self.cost = 0
        self.completed_workflows = 0
        self.workflows = workflows

    def assign_task(self, task, device):
        with device.resource.request() as req:
            yield req
            instructions = task.instructions
            execution_time = instructions / device.mips
            yield self.env.timeout(execution_time)
            self.cost += execution_time * device.cost_per_hour
            task.executed = True
            task.execution_time = execution_time
            device.queue.popleft()
            print(f"Task {task.id} of workflow {task.workflow_id} completed on {device.id} at time {self.env.now}")

            # Check if the workflow is completed
            workflow = next(wf for wf in self.workflows if wf.id == task.workflow_id)
            self.check_workflow_completion(workflow)


    def get_device_by_id(self, device_id):
        for device in self.iot_devices + self.fog_nodes + self.cloud_servers:
            if device.id == device_id:
                return device
        return None

    def check_workflow_completion(self, workflow):
        # Check if all tasks in the workflow are executed
        if all(task.executed for task in workflow.tasks.values()):
            self.completed_workflows += 1  # Increment completed workflows counter
            print(f"Workflow {workflow.id} is completed! Total completed workflows: {self.completed_workflows}")





def process_workflow(env, workflow, fog_env, agent):
      while(True):
        if all([task.executed for task in workflow.tasks.values()]):
          break
        for task in workflow.tasks.values():
            if task.executed:
              continue
            if all([parent.executed for parent in task.parents]) or task.parents == []:
                action = agent.choose_action()
                devices = fog_env.iot_devices + fog_env.fog_nodes + fog_env.cloud_servers
                device = devices[action]
                device.add_task_to_queue(task)
                yield env.process(fog_env.assign_task(task, device))

# %% [markdown]
# # class NewSim

# %%
class  NewSim:
    def __init__(self, num_iot, num_fog, num_server):
        self.num_iot = num_iot
        self.num_fog = num_fog
        self.num_server = num_server
        self.num_totla_dev = num_iot + num_fog + num_server
        self.env = simpy.Environment()
        self.reset()
        self.run()

    def reset(self):
        self.iot_devices = [Device(f'iot_{i}', 500, 0, self.env) for i in range(self.num_iot)]
        self.fog_devices = [Device(f'fog_{i}', 4000, 1, self.env) for i in range(self.num_fog)]
        self.server_devices = [Device(f'server_{i}', 6000, 8, self.env) for i in range(self.num_server)]
        self.agent = RandomAgent(action_size=self.num_totla_dev)
        self.workflows = ensemble_of_workflows(name = 'CyberShake', size=100, distribution = 'constant', dax_path="/content/drive/My Drive/Zahra/dax/")

    def run(self):
        fog_env = FogEnv(self.env, self.iot_devices, self.fog_devices, self.server_devices,self.workflows)
        for workflow in self.workflows:
                self.env.process(process_workflow(self.env, workflow, fog_env, self.agent))

        self.env.run()  # Run simulation for a time period

# %% [markdown]
# # run simulation

# %%
simulation = NewSim(num_iot=10, num_fog=8, num_server=5)
# Out:
# Streaming output truncated to the last 5000 lines.
# Task ID00053 of workflow 40 completed on server_2 at time 15.854340833333348
# Task ID00054 of workflow 23 completed on iot_0 at time 15.856276666666684
# Task ID00033 of workflow 33 completed on iot_2 at time 15.858320000000036
# Task ID00043 of workflow 64 completed on iot_0 at time 15.858976666666685
# Task ID00071 of workflow 72 completed on fog_0 at time 15.85961916666668
# Task ID00054 of workflow 40 completed on fog_0 at time 15.859911666666681
# Task ID00072 of workflow 72 completed on fog_4 at time 15.85994916666668
# Task ID00032 of workflow 92 completed on iot_2 at time 15.861280000000036
# Task ID00036 of workflow 13 completed on fog_7 at time 15.862282500000017
# Task ID00030 of workflow 70 completed on iot_2 at time 15.862860000000037
# Task ID00029 of workflow 97 completed on fog_3 at time 15.866354166666682
# Task ID00030 of workflow 97 completed on fog_4 at time 15.866551666666682
# Task ID00031 of workflow 70 completed on server_3 at time 15.869901666666703
# Task ID00032 of workflow 70 completed on fog_0 at time 15.870271666666703
# Task ID00049 of workflow 19 completed on iot_4 at time 15.876632500000015
# Task ID00050 of workflow 19 completed on iot_3 at time 15.878112500000016
# Task ID00033 of workflow 70 completed on fog_2 at time 15.891261666666702
# Task ID00044 of workflow 64 completed on server_4 at time 15.89214833333335
# Task ID00049 of workflow 43 completed on iot_8 at time 15.895500000000034
# Task ID00050 of workflow 43 completed on fog_3 at time 15.895685000000034
# Task ID00045 of workflow 64 completed on fog_5 at time 15.89843083333335
# Task ID00046 of workflow 64 completed on fog_4 at time 15.898595833333351
# Task ID00047 of workflow 64 completed on fog_0 at time 15.905250833333351
# Task ID00048 of workflow 64 completed on server_1 at time 15.905412500000018
# Task ID00055 of workflow 47 completed on iot_6 at time 15.905878333333352
# Task ID00033 of workflow 92 completed on server_4 at time 15.906141666666684
# Task ID00056 of workflow 47 completed on fog_3 at time 15.906190833333351
# Task ID00036 of workflow 53 completed on iot_7 at time 15.909758333333347
# Task ID00060 of workflow 15 completed on iot_5 at time 15.910028333333349
# Task ID00034 of workflow 92 completed on fog_6 at time 15.916051666666684
# Task ID00042 of workflow 45 completed on iot_2 at time 15.932800000000038
# Task ID00073 of workflow 60 completed on iot_0 at time 15.950956666666684
# Task ID00074 of workflow 60 completed on fog_4 at time 15.951229166666684
# Task ID00034 of workflow 33 completed on iot_4 at time 15.955912500000016
# Task ID00035 of workflow 33 completed on server_4 at time 15.956079166666683
# Task ID00057 of workflow 47 completed on fog_6 at time 15.959029166666683
# Task ID00061 of workflow 15 completed on fog_6 at time 15.959366666666684
# Task ID00043 of workflow 45 completed on fog_6 at time 15.959704166666684
# Task ID00086 of workflow 75 completed on iot_9 at time 15.962235000000014
# Task ID00036 of workflow 33 completed on server_1 at time 15.962547500000017
# Task ID00052 of workflow 10 completed on iot_9 at time 15.964835000000013
# Task ID00062 of workflow 15 completed on fog_5 at time 15.971854166666684
# Task ID00063 of workflow 15 completed on server_3 at time 15.972074166666685
# Task ID00087 of workflow 75 completed on fog_5 at time 15.972189166666684
# Task ID00053 of workflow 10 completed on fog_0 at time 15.975020000000013
# Task ID00049 of workflow 99 completed on iot_7 at time 15.986038333333347
# Task ID00050 of workflow 99 completed on fog_0 at time 15.986223333333347
# Task ID00076 of workflow 44 completed on iot_7 at time 15.987698333333347
# Task ID00080 of workflow 90 completed on iot_7 at time 15.989698333333347
# Task ID00051 of workflow 19 completed on iot_3 at time 15.998812500000016
# Task ID00052 of workflow 19 completed on fog_4 at time 15.999137500000016
# Task ID00077 of workflow 44 completed on fog_0 at time 16.000645833333348
# Task ID00073 of workflow 72 completed on iot_5 at time 16.00200833333335
# Task ID00074 of workflow 72 completed on fog_3 at time 16.00228083333335
# Task ID00035 of workflow 92 completed on iot_5 at time 16.00400833333335
# Task ID00053 of workflow 19 completed on fog_2 at time 16.009322500000017
# Task ID00044 of workflow 45 completed on fog_1 at time 16.009461666666684
# Task ID00054 of workflow 19 completed on fog_5 at time 16.009615000000018
# Task ID00075 of workflow 72 completed on fog_0 at time 16.012918333333353
# Task ID00055 of workflow 40 completed on iot_4 at time 16.026192500000015
# Task ID00056 of workflow 40 completed on fog_6 at time 16.026505000000014
# Task ID00051 of workflow 54 completed on iot_6 at time 16.02657833333335
# Task ID00052 of workflow 54 completed on fog_6 at time 16.02690333333335
# Task ID00054 of workflow 10 completed on iot_4 at time 16.028532500000015
# Task ID00055 of workflow 10 completed on server_3 at time 16.03438916666668
# Task ID00053 of workflow 54 completed on fog_6 at time 16.03708833333335
# Task ID00054 of workflow 54 completed on fog_7 at time 16.03738083333335
# Task ID00049 of workflow 87 completed on iot_9 at time 16.041115000000012
# Task ID00050 of workflow 87 completed on fog_0 at time 16.04130000000001
# Task ID00058 of workflow 47 completed on iot_3 at time 16.043392500000017
# Task ID00059 of workflow 47 completed on fog_3 at time 16.04363250000002
# Task ID00055 of workflow 54 completed on fog_1 at time 16.04616583333335
# Task ID00056 of workflow 54 completed on server_0 at time 16.046374166666684
# Task ID00060 of workflow 47 completed on server_1 at time 16.05030250000002
# Task ID00051 of workflow 85 completed on iot_2 at time 16.05350000000004
# Task ID00049 of workflow 51 completed on iot_7 at time 16.065978333333348
# Task ID00026 of workflow 79 completed on iot_7 at time 16.06867833333335
# Task ID00027 of workflow 79 completed on server_4 at time 16.074351666666683
# Task ID00055 of workflow 19 completed on iot_0 at time 16.07989500000002
# Task ID00076 of workflow 72 completed on iot_0 at time 16.08155500000002
# Task ID00057 of workflow 54 completed on fog_3 at time 16.089351666666683
# Task ID00052 of workflow 85 completed on fog_3 at time 16.089676666666684
# Task ID00077 of workflow 72 completed on server_0 at time 16.090186666666686
# Task ID00078 of workflow 72 completed on fog_7 at time 16.090481666666687
# Task ID00058 of workflow 54 completed on server_1 at time 16.093066666666683
# Task ID00059 of workflow 54 completed on iot_5 at time 16.09498666666668
# Task ID00079 of workflow 72 completed on server_2 at time 16.09921666666669
# Task ID00080 of workflow 72 completed on fog_6 at time 16.09946666666669
# Task ID00053 of workflow 85 completed on fog_0 at time 16.099861666666683
# Task ID00045 of workflow 24 completed on iot_2 at time 16.10376000000004
# Task ID00060 of workflow 54 completed on fog_7 at time 16.10499166666668
# Task ID00054 of workflow 85 completed on fog_7 at time 16.10528416666668
# Task ID00034 of workflow 70 completed on iot_6 at time 16.10585833333335
# Task ID00074 of workflow 12 completed on iot_2 at time 16.10594000000004
# Task ID00035 of workflow 70 completed on fog_1 at time 16.106108333333353
# Task ID00061 of workflow 54 completed on iot_5 at time 16.107691666666682
# Task ID00055 of workflow 85 completed on server_2 at time 16.111140833333348
# Task ID00031 of workflow 97 completed on iot_9 at time 16.12561500000001
# Task ID00055 of workflow 23 completed on iot_7 at time 16.13895833333335
# Task ID00037 of workflow 13 completed on iot_7 at time 16.14125833333335
# Task ID00037 of workflow 53 completed on iot_7 at time 16.143558333333353
# Task ID00038 of workflow 13 completed on server_4 at time 16.147800000000018
# Task ID00039 of workflow 13 completed on fog_5 at time 16.147962500000016
# Task ID00051 of workflow 99 completed on iot_4 at time 16.149232500000014
# Task ID00052 of workflow 99 completed on fog_7 at time 16.149557500000014
# Task ID00038 of workflow 53 completed on server_0 at time 16.15010000000002
# Task ID00039 of workflow 53 completed on server_0 at time 16.150208333333353
# Task ID00056 of workflow 10 completed on iot_4 at time 16.151732500000016
# Task ID00050 of workflow 51 completed on iot_4 at time 16.153212500000016
# Task ID00040 of workflow 13 completed on fog_4 at time 16.153520000000015
# Task ID00040 of workflow 53 completed on server_4 at time 16.153913333333353
# Task ID00046 of workflow 24 completed on iot_4 at time 16.154532500000016
# Task ID00053 of workflow 99 completed on fog_2 at time 16.159742500000014
# Task ID00064 of workflow 15 completed on iot_3 at time 16.159852500000017
# Task ID00065 of workflow 15 completed on iot_5 at time 16.162692500000016
# Task ID00051 of workflow 51 completed on fog_7 at time 16.168300000000016
# Task ID00054 of workflow 99 completed on fog_7 at time 16.168592500000017
# Task ID00045 of workflow 45 completed on iot_9 at time 16.175875000000012
# Task ID00046 of workflow 45 completed on server_0 at time 16.17598500000001
# Task ID00034 of workflow 84 completed on iot_2 at time 16.18522000000004
# Task ID00035 of workflow 84 completed on server_1 at time 16.185386666666705
# Task ID00057 of workflow 10 completed on fog_6 at time 16.194710000000015
# Task ID00058 of workflow 10 completed on server_2 at time 16.198425000000015
# Task ID00066 of workflow 15 completed on fog_6 at time 16.207790000000013
# Task ID00067 of workflow 15 completed on iot_0 at time 16.209690000000013
# Task ID00068 of workflow 15 completed on fog_0 at time 16.21612250000001
# Task ID00051 of workflow 43 completed on iot_6 at time 16.22655833333335
# Task ID00037 of workflow 33 completed on iot_6 at time 16.228858333333353
# Task ID00044 of workflow 42 completed on iot_1 at time 16.235836666666685
# Task ID00038 of workflow 33 completed on fog_4 at time 16.23867083333335
# Task ID00039 of workflow 33 completed on fog_2 at time 16.23883333333335
# Task ID00057 of workflow 63 completed on iot_8 at time 16.239320000000035
# Task ID00045 of workflow 42 completed on server_3 at time 16.240025000000017
# Task ID00046 of workflow 42 completed on fog_5 at time 16.240190000000016
# Task ID00054 of workflow 7 completed on iot_8 at time 16.241660000000035
# Task ID00058 of workflow 63 completed on server_4 at time 16.243035000000035
# Task ID00047 of workflow 42 completed on server_2 at time 16.244626666666683
# Task ID00055 of workflow 7 completed on fog_1 at time 16.250445000000035
# Task ID00048 of workflow 42 completed on fog_1 at time 16.250687500000033
# Task ID00056 of workflow 7 completed on iot_5 at time 16.252945000000036
# Task ID00049 of workflow 42 completed on server_1 at time 16.2570441666667
# Task ID00036 of workflow 84 completed on iot_7 at time 16.263006666666705
# Task ID00034 of workflow 28 completed on iot_2 at time 16.26450000000004
# Task ID00035 of workflow 28 completed on server_0 at time 16.264666666666706
# Task ID00052 of workflow 43 completed on iot_7 at time 16.265606666666706
# Task ID00059 of workflow 14 completed on iot_2 at time 16.26642000000004
# Task ID00037 of workflow 84 completed on iot_7 at time 16.267906666666708
# Task ID00065 of workflow 98 completed on iot_2 at time 16.26926000000004
# Task ID00036 of workflow 28 completed on fog_3 at time 16.274369166666705
# Task ID00060 of workflow 14 completed on fog_6 at time 16.27642500000004
# Task ID00038 of workflow 84 completed on fog_4 at time 16.277719166666706
# Task ID00037 of workflow 28 completed on fog_4 at time 16.278006666666705
# Task ID00066 of workflow 98 completed on fog_3 at time 16.287449166666704
# Task ID00088 of workflow 75 completed on iot_3 at time 16.28745250000002
# Task ID00067 of workflow 98 completed on server_2 at time 16.28760750000004
# Task ID00068 of workflow 98 completed on fog_3 at time 16.294040000000038
# Task ID00057 of workflow 7 completed on fog_0 at time 16.295922500000035
# Task ID00069 of workflow 98 completed on iot_5 at time 16.296040000000037
# Task ID00081 of workflow 90 completed on iot_6 at time 16.296878333333353
# Task ID00082 of workflow 90 completed on fog_4 at time 16.297180833333353
# Task ID00061 of workflow 47 completed on iot_6 at time 16.299578333333354
# Task ID00058 of workflow 7 completed on fog_5 at time 16.301495000000035
# Task ID00056 of workflow 23 completed on iot_6 at time 16.302078333333355
# Task ID00053 of workflow 26 completed on iot_1 at time 16.317316666666684
# Task ID00032 of workflow 3 completed on iot_1 at time 16.320276666666686
# Task ID00060 of workflow 49 completed on iot_8 at time 16.321700000000035
# Task ID00061 of workflow 49 completed on fog_0 at time 16.322037500000036
# Task ID00070 of workflow 98 completed on server_0 at time 16.33000333333337
# Task ID00054 of workflow 26 completed on server_0 at time 16.33019833333337
# Task ID00057 of workflow 23 completed on server_2 at time 16.33073000000002
# Task ID00033 of workflow 3 completed on server_4 at time 16.334270000000018
# Task ID00071 of workflow 98 completed on fog_7 at time 16.33736833333337
# Task ID00072 of workflow 98 completed on fog_2 at time 16.33769833333337
# Task ID00055 of workflow 26 completed on fog_1 at time 16.33898333333337
# Task ID00034 of workflow 3 completed on fog_3 at time 16.34418000000002
# Task ID00058 of workflow 23 completed on fog_1 at time 16.34455583333337
# Task ID00056 of workflow 26 completed on fog_1 at time 16.34486833333337
# Task ID00035 of workflow 3 completed on iot_7 at time 16.346180000000018
# Task ID00036 of workflow 57 completed on iot_2 at time 16.346880000000038
# Task ID00037 of workflow 57 completed on server_0 at time 16.347071666666704
# Task ID00036 of workflow 3 completed on fog_5 at time 16.355882500000018
# Task ID00057 of workflow 26 completed on fog_3 at time 16.38784583333337
# Task ID00045 of workflow 29 completed on iot_2 at time 16.39714000000004
# Task ID00046 of workflow 29 completed on server_1 at time 16.39725000000004
# Task ID00038 of workflow 57 completed on fog_3 at time 16.397658333333368
# Task ID00039 of workflow 57 completed on iot_4 at time 16.39895833333337
# Task ID00062 of workflow 47 completed on iot_0 at time 16.399478333333356
# Task ID00059 of workflow 23 completed on iot_0 at time 16.401398333333354
# Task ID00047 of workflow 29 completed on server_3 at time 16.401686666666706
# Task ID00063 of workflow 47 completed on server_3 at time 16.401906666666704
# Task ID00051 of workflow 87 completed on iot_3 at time 16.408152500000018
# Task ID00028 of workflow 79 completed on iot_3 at time 16.410532500000016
# Task ID00060 of workflow 23 completed on fog_1 at time 16.411403333333354
# Task ID00064 of workflow 47 completed on server_1 at time 16.411611666666705
# Task ID00065 of workflow 47 completed on fog_7 at time 16.411966666666704
# Task ID00066 of workflow 47 completed on fog_0 at time 16.425046666666702
# Task ID00067 of workflow 47 completed on fog_0 at time 16.425284166666703
# Task ID00068 of workflow 47 completed on server_3 at time 16.429572500000038
# Task ID00069 of workflow 47 completed on fog_1 at time 16.42982250000004
# Task ID00040 of workflow 57 completed on iot_7 at time 16.44341833333337
# Task ID00041 of workflow 57 completed on fog_1 at time 16.44367583333337
# Task ID00058 of workflow 26 completed on iot_0 at time 16.445978333333354
# Task ID00059 of workflow 26 completed on fog_1 at time 16.446218333333356
# Task ID00048 of workflow 29 completed on iot_0 at time 16.447918333333355
# Task ID00052 of workflow 87 completed on iot_0 at time 16.450518333333356
# Task ID00061 of workflow 23 completed on iot_0 at time 16.453218333333357
# Task ID00062 of workflow 23 completed on fog_6 at time 16.465705833333356
# Task ID00063 of workflow 23 completed on fog_4 at time 16.466035833333358
# Task ID00064 of workflow 23 completed on server_2 at time 16.475740833333358
# Task ID00081 of workflow 72 completed on iot_3 at time 16.478552500000017
# Task ID00082 of workflow 72 completed on server_1 at time 16.478754166666683
# Task ID00070 of workflow 47 completed on fog_5 at time 16.480767500000038
# Task ID00071 of workflow 47 completed on server_4 at time 16.485677500000037
# Task ID00033 of workflow 93 completed on iot_1 at time 16.488196666666685
# Task ID00034 of workflow 93 completed on server_3 at time 16.49480333333335
# Task ID00035 of workflow 93 completed on server_2 at time 16.494970000000016
# Task ID00064 of workflow 50 completed on iot_2 at time 16.51360000000004
# Task ID00065 of workflow 50 completed on server_4 at time 16.513836666666705
# Task ID00050 of workflow 62 completed on iot_2 at time 16.51508000000004
# Task ID00057 of workflow 40 completed on iot_9 at time 16.519695000000013
# Task ID00041 of workflow 53 completed on iot_9 at time 16.521755000000013
# Task ID00058 of workflow 40 completed on server_2 at time 16.523410000000013
# Task ID00059 of workflow 40 completed on server_3 at time 16.523570000000014
# Task ID00051 of workflow 62 completed on fog_1 at time 16.53016750000004
# Task ID00042 of workflow 53 completed on fog_7 at time 16.530497500000013
# Task ID00043 of workflow 53 completed on fog_0 at time 16.530835000000014
# Task ID00053 of workflow 87 completed on iot_7 at time 16.531998333333355
# Task ID00045 of workflow 4 completed on iot_1 at time 16.538456666666686
# Task ID00046 of workflow 4 completed on fog_3 at time 16.538621666666685
# Task ID00060 of workflow 40 completed on fog_1 at time 16.54017250000004
# Task ID00061 of workflow 40 completed on iot_4 at time 16.54287250000004
# Task ID00045 of workflow 16 completed on iot_2 at time 16.56534000000004
# Task ID00047 of workflow 24 completed on iot_9 at time 16.574995000000012
# Task ID00059 of workflow 10 completed on iot_9 at time 16.57691500000001
# Task ID00062 of workflow 54 completed on iot_3 at time 16.57845250000002
# Task ID00089 of workflow 75 completed on iot_9 at time 16.57923500000001
# Task ID00056 of workflow 85 completed on iot_3 at time 16.58095250000002
# Task ID00058 of workflow 20 completed on iot_1 at time 16.583036666666686
# Task ID00065 of workflow 23 completed on iot_3 at time 16.58379250000002
# Task ID00047 of workflow 4 completed on iot_0 at time 16.591861666666684
# Task ID00057 of workflow 85 completed on server_3 at time 16.609604166666685
# Task ID00036 of workflow 93 completed on iot_7 at time 16.609618333333355
# Task ID00037 of workflow 93 completed on server_3 at time 16.60981000000002
# Task ID00058 of workflow 85 completed on server_2 at time 16.613319166666685
# Task ID00059 of workflow 85 completed on fog_7 at time 16.613559166666686
# Task ID00066 of workflow 50 completed on iot_5 at time 16.618476666666705
# Task ID00067 of workflow 50 completed on server_3 at time 16.61863500000004
# Task ID00038 of workflow 93 completed on server_2 at time 16.61986083333335
# Task ID00039 of workflow 93 completed on iot_6 at time 16.621160833333352
# Task ID00060 of workflow 85 completed on fog_1 at time 16.623564166666686
# Task ID00061 of workflow 85 completed on server_0 at time 16.623789166666686
# Task ID00068 of workflow 50 completed on fog_1 at time 16.629996666666685
# Task ID00069 of workflow 50 completed on server_0 at time 16.63016333333335
# Task ID00040 of workflow 93 completed on iot_3 at time 16.665620833333353
# Task ID00041 of workflow 93 completed on fog_5 at time 16.665878333333353
# Task ID00077 of workflow 56 completed on iot_2 at time 16.668920000000043
# Task ID00069 of workflow 46 completed on iot_2 at time 16.67092000000004
# Task ID00039 of workflow 89 completed on iot_2 at time 16.672220000000042
# Task ID00062 of workflow 40 completed on iot_0 at time 16.691761666666686
# Task ID00046 of workflow 16 completed on iot_0 at time 16.693081666666686
# Task ID00048 of workflow 24 completed on iot_0 at time 16.695021666666687
# Task ID00083 of workflow 90 completed on iot_9 at time 16.69563500000001
# Task ID00084 of workflow 90 completed on fog_7 at time 16.69584500000001
# Task ID00059 of workflow 7 completed on iot_9 at time 16.69755500000001
# Task ID00047 of workflow 16 completed on fog_1 at time 16.699736666666684
# Task ID00037 of workflow 3 completed on iot_9 at time 16.69985500000001
# Task ID00048 of workflow 16 completed on server_4 at time 16.69989833333335
# Task ID00049 of workflow 24 completed on server_2 at time 16.701378333333352
# Task ID00050 of workflow 24 completed on server_0 at time 16.701501666666687
# Task ID00090 of workflow 75 completed on iot_4 at time 16.70631500000001
# Task ID00060 of workflow 7 completed on fog_3 at time 16.707560000000008
# Task ID00049 of workflow 16 completed on fog_5 at time 16.70943333333335
# Task ID00050 of workflow 16 completed on fog_3 at time 16.70961833333335
# Task ID00038 of workflow 3 completed on fog_1 at time 16.70966750000001
# Task ID00039 of workflow 3 completed on server_3 at time 16.709775833333342
# Task ID00091 of workflow 75 completed on fog_1 at time 16.70996000000001
# Task ID00040 of workflow 3 completed on fog_5 at time 16.71533333333334
# Task ID00051 of workflow 24 completed on fog_4 at time 16.716589166666687
# Task ID00052 of workflow 24 completed on fog_1 at time 16.716914166666687
# Task ID00041 of workflow 3 completed on iot_3 at time 16.71739333333334
# Task ID00044 of workflow 71 completed on iot_8 at time 16.719760000000036
# Task ID00070 of workflow 46 completed on fog_0 at time 16.72186500000004
# Task ID00056 of workflow 77 completed on iot_8 at time 16.722260000000038
# Task ID00062 of workflow 85 completed on iot_6 at time 16.723689166666688
# Task ID00053 of workflow 24 completed on server_2 at time 16.723704166666685
# Task ID00092 of workflow 75 completed on fog_6 at time 16.72392000000001
# Task ID00063 of workflow 85 completed on server_2 at time 16.723924166666684
# Task ID00054 of workflow 24 completed on fog_6 at time 16.72421250000001
# Task ID00069 of workflow 30 completed on iot_8 at time 16.724260000000037
# Task ID00051 of workflow 16 completed on fog_3 at time 16.72470583333335
# Task ID00052 of workflow 16 completed on server_2 at time 16.724922500000016
# Task ID00048 of workflow 32 completed on iot_8 at time 16.726200000000038
# Task ID00053 of workflow 16 completed on server_2 at time 16.731712500000015
# Task ID00054 of workflow 16 completed on server_3 at time 16.731907500000016
# Task ID00042 of workflow 93 completed on iot_5 at time 16.735818333333352
# Task ID00043 of workflow 93 completed on fog_1 at time 16.736155833333353
# Task ID00055 of workflow 16 completed on server_4 at time 16.737764166666683
# Task ID00085 of workflow 90 completed on fog_2 at time 16.73872750000001
# Task ID00064 of workflow 85 completed on fog_6 at time 16.73877000000001
# Task ID00056 of workflow 16 completed on iot_0 at time 16.740264166666684
# Task ID00040 of workflow 89 completed on iot_4 at time 16.75077500000001
# Task ID00057 of workflow 77 completed on server_0 at time 16.750911666666703
# Task ID00093 of workflow 75 completed on server_0 at time 16.75102833333337
# Task ID00041 of workflow 89 completed on fog_7 at time 16.75103250000001
# Task ID00061 of workflow 7 completed on iot_4 at time 16.753475000000012
# Task ID00042 of workflow 89 completed on server_3 at time 16.756860833333345
# Task ID00043 of workflow 89 completed on server_2 at time 16.757085833333345
# Task ID00086 of workflow 90 completed on server_0 at time 16.760945000000035
# Task ID00062 of workflow 7 completed on server_4 at time 16.76180000000001
# Task ID00042 of workflow 57 completed on iot_9 at time 16.76979500000001
# Task ID00043 of workflow 57 completed on fog_3 at time 16.77013250000001
# Task ID00070 of workflow 30 completed on fog_5 at time 16.775205000000035
# Task ID00071 of workflow 30 completed on server_1 at time 16.780115000000034
# Task ID00072 of workflow 30 completed on server_2 at time 16.780335000000033
# Task ID00071 of workflow 46 completed on iot_7 at time 16.78078500000004
# Task ID00049 of workflow 32 completed on fog_5 at time 16.784740000000035
# Task ID00063 of workflow 7 completed on fog_5 at time 16.785070000000037
# Task ID00073 of workflow 30 completed on server_1 at time 16.788000000000032
# Task ID00074 of workflow 30 completed on fog_2 at time 16.788272500000033
# Task ID00051 of workflow 9 completed on iot_2 at time 16.79292000000004
# Task ID00044 of workflow 89 completed on server_0 at time 16.794116666666703
# Task ID00061 of workflow 36 completed on iot_2 at time 16.795620000000042
# Task ID00050 of workflow 96 completed on iot_2 at time 16.797100000000043
# Task ID00045 of workflow 89 completed on fog_1 at time 16.800399166666704
# Task ID00064 of workflow 7 completed on server_0 at time 16.803821666666703
# Task ID00062 of workflow 36 completed on server_4 at time 16.80394500000004
# Task ID00063 of workflow 36 completed on fog_6 at time 16.804275000000043
# Task ID00034 of workflow 82 completed on iot_8 at time 16.80548000000004
# Task ID00035 of workflow 82 completed on fog_3 at time 16.80573000000004
# Task ID00042 of workflow 3 completed on iot_5 at time 16.80575833333335
# Task ID00043 of workflow 3 completed on server_3 at time 16.80598333333335
# Task ID00037 of workflow 55 completed on iot_8 at time 16.80778000000004
# Task ID00043 of workflow 6 completed on iot_8 at time 16.81048000000004
# Task ID00041 of workflow 41 completed on iot_8 at time 16.81254000000004
# Task ID00038 of workflow 55 completed on fog_3 at time 16.81759250000004
# Task ID00042 of workflow 41 completed on fog_1 at time 16.82128250000004
# Task ID00043 of workflow 41 completed on fog_1 at time 16.821620000000042
# Task ID00060 of workflow 26 completed on iot_9 at time 16.84983500000001
# Task ID00061 of workflow 26 completed on fog_0 at time 16.85017250000001
# Task ID00044 of workflow 41 completed on server_4 at time 16.85479166666671
# Task ID00045 of workflow 71 completed on iot_5 at time 16.856018333333353
# Task ID00044 of workflow 6 completed on fog_4 at time 16.86023750000004
# Task ID00062 of workflow 26 completed on fog_6 at time 16.86266000000001
# Task ID00045 of workflow 95 completed on iot_8 at time 16.862800000000043
# Task ID00063 of workflow 26 completed on server_4 at time 16.862880000000008
# Task ID00046 of workflow 95 completed on fog_4 at time 16.86296500000004
# Task ID00030 of workflow 73 completed on iot_8 at time 16.864380000000043
# Task ID00050 of workflow 11 completed on iot_8 at time 16.865860000000044
# Task ID00047 of workflow 95 completed on fog_3 at time 16.86962000000004
# Task ID00048 of workflow 95 completed on iot_7 at time 16.87156000000004
# Task ID00075 of workflow 30 completed on iot_0 at time 16.873372500000034
# Task ID00049 of workflow 64 completed on iot_2 at time 16.873380000000044
# Task ID00076 of workflow 30 completed on fog_1 at time 16.873580000000032
# Task ID00039 of workflow 55 completed on iot_0 at time 16.874672500000035
# Task ID00031 of workflow 73 completed on fog_0 at time 16.874942500000042
# Task ID00032 of workflow 73 completed on fog_0 at time 16.875312500000042
# Task ID00046 of workflow 71 completed on iot_0 at time 16.875992500000034
# Task ID00049 of workflow 95 completed on fog_5 at time 16.88109500000004
# Task ID00050 of workflow 95 completed on server_0 at time 16.881218333333376
# Task ID00077 of workflow 30 completed on fog_6 at time 16.88652750000003
# Task ID00078 of workflow 30 completed on fog_0 at time 16.886822500000033
# Task ID00051 of workflow 95 completed on server_3 at time 16.89127666666671
# Task ID00033 of workflow 73 completed on fog_5 at time 16.902085000000042
# Task ID00079 of workflow 30 completed on fog_5 at time 16.91518750000004
# Task ID00080 of workflow 30 completed on server_3 at time 16.915354166666706
# Task ID00047 of workflow 31 completed on iot_8 at time 16.919100000000043
# Task ID00040 of workflow 55 completed on iot_7 at time 16.919132500000035
# Task ID00048 of workflow 31 completed on server_0 at time 16.91926166666671
# Task ID00081 of workflow 30 completed on server_4 at time 16.92102250000004
# Task ID00041 of workflow 55 completed on iot_7 at time 16.921192500000036
# Task ID00082 of workflow 30 completed on server_0 at time 16.921224166666704
# Task ID00074 of workflow 25 completed on iot_8 at time 16.921280000000042
# Task ID00049 of workflow 29 completed on iot_9 at time 16.92611500000001
# Task ID00050 of workflow 29 completed on iot_0 at time 16.92759500000001
# Task ID00075 of workflow 25 completed on server_2 at time 16.92837166666671
# Task ID00076 of workflow 25 completed on fog_1 at time 16.928579166666708
# Task ID00049 of workflow 31 completed on fog_6 at time 16.92879666666671
# Task ID00042 of workflow 55 completed on fog_3 at time 16.929935000000036
# Task ID00043 of workflow 55 completed on fog_5 at time 16.930272500000036
# Task ID00083 of workflow 30 completed on fog_0 at time 16.935774166666704
# Task ID00077 of workflow 25 completed on fog_7 at time 16.941526666666707
# Task ID00078 of workflow 25 completed on fog_7 at time 16.94182166666671
# Task ID00051 of workflow 29 completed on fog_3 at time 16.945022500000036
# Task ID00052 of workflow 29 completed on server_1 at time 16.945239166666703
# Task ID00053 of workflow 29 completed on fog_1 at time 16.955424166666702
# Task ID00054 of workflow 29 completed on fog_3 at time 16.955716666666703
# Task ID00075 of workflow 60 completed on iot_2 at time 16.958480000000044
# Task ID00076 of workflow 60 completed on fog_5 at time 16.958687500000043
# Task ID00044 of workflow 34 completed on iot_1 at time 16.981096666666687
# Task ID00045 of workflow 34 completed on server_2 at time 16.98528500000002
# Task ID00044 of workflow 55 completed on fog_0 at time 16.985531666666702
# Task ID00045 of workflow 55 completed on fog_1 at time 16.991814166666703
# Task ID00046 of workflow 55 completed on fog_0 at time 16.991979166666702
# Task ID00047 of workflow 55 completed on fog_6 at time 16.9986341666667
# Task ID00036 of workflow 92 completed on iot_2 at time 17.036100000000044
# Task ID00037 of workflow 92 completed on fog_0 at time 17.036387500000043
# Task ID00032 of workflow 97 completed on iot_2 at time 17.039060000000045
# Task ID00083 of workflow 72 completed on iot_9 at time 17.04251500000001
# Task ID00072 of workflow 47 completed on iot_9 at time 17.04515500000001
# Task ID00038 of workflow 92 completed on fog_3 at time 17.04620000000004
# Task ID00079 of workflow 25 completed on iot_0 at time 17.04664166666671
# Task ID00073 of workflow 47 completed on server_2 at time 17.052820000000008
# Task ID00074 of workflow 47 completed on fog_4 at time 17.05309250000001
# Task ID00055 of workflow 99 completed on iot_2 at time 17.109340000000046
# Task ID00056 of workflow 99 completed on server_2 at time 17.10954833333338
# Task ID00059 of workflow 63 completed on iot_2 at time 17.111260000000044
# Task ID00061 of workflow 14 completed on iot_2 at time 17.113960000000045
# Task ID00063 of workflow 54 completed on iot_2 at time 17.116600000000044
# Task ID00078 of workflow 56 completed on iot_2 at time 17.118960000000044
# Task ID00079 of workflow 56 completed on fog_5 at time 17.132062500000043
# Task ID00033 of workflow 74 completed on iot_1 at time 17.149016666666686
# Task ID00039 of workflow 21 completed on iot_1 at time 17.150316666666686
# Task ID00044 of workflow 93 completed on iot_4 at time 17.151535000000013
# Task ID00078 of workflow 0 completed on iot_1 at time 17.152676666666686
# Task ID00050 of workflow 32 completed on iot_4 at time 17.153015000000014
# Task ID00032 of workflow 81 completed on iot_1 at time 17.155636666666688
# Task ID00043 of workflow 78 completed on iot_1 at time 17.15833666666669
# Task ID00079 of workflow 0 completed on server_2 at time 17.161411666666687
# Task ID00051 of workflow 32 completed on fog_7 at time 17.168102500000014
# Task ID00044 of workflow 57 completed on iot_3 at time 17.16819250000001
# Task ID00052 of workflow 32 completed on server_1 at time 17.16831916666668
# Task ID00052 of workflow 9 completed on iot_3 at time 17.17079250000001
# Task ID00033 of workflow 81 completed on fog_3 at time 17.17662666666669
# Task ID00053 of workflow 32 completed on fog_6 at time 17.17850416666668
# Task ID00054 of workflow 32 completed on fog_5 at time 17.17879666666668
# Task ID00045 of workflow 57 completed on fog_3 at time 17.18290916666669
# Task ID00055 of workflow 32 completed on server_1 at time 17.184653333333348
# Task ID00057 of workflow 16 completed on iot_5 at time 17.199838333333354
# Task ID00044 of workflow 3 completed on iot_6 at time 17.204043333333352
# Task ID00050 of workflow 64 completed on iot_6 at time 17.205523333333353
# Task ID00044 of workflow 78 completed on fog_2 at time 17.208094166666687
# Task ID00045 of workflow 3 completed on fog_0 at time 17.210325833333354
# Task ID00034 of workflow 74 completed on iot_7 at time 17.228296666666687
# Task ID00064 of workflow 36 completed on iot_2 at time 17.235420000000044
# Task ID00065 of workflow 36 completed on fog_1 at time 17.235775000000043
# Task ID00058 of workflow 77 completed on iot_5 at time 17.244418333333353
# Task ID00059 of workflow 77 completed on fog_6 at time 17.244658333333355
# Task ID00036 of workflow 82 completed on iot_3 at time 17.24841250000001
# Task ID00037 of workflow 82 completed on iot_0 at time 17.250712500000013
# Task ID00060 of workflow 77 completed on server_3 at time 17.251328333333355
# Task ID00061 of workflow 77 completed on server_3 at time 17.251553333333355
# Task ID00062 of workflow 77 completed on server_1 at time 17.259878333333354
# Task ID00063 of workflow 77 completed on server_3 at time 17.260098333333353
# Task ID00057 of workflow 37 completed on iot_8 at time 17.265100000000043
# Task ID00078 of workflow 22 completed on iot_8 at time 17.267460000000042
# Task ID00037 of workflow 8 completed on iot_8 at time 17.269760000000044
# Task ID00058 of workflow 37 completed on fog_5 at time 17.270672500000043
# Task ID00079 of workflow 22 completed on server_4 at time 17.276195000000044
# Task ID00080 of workflow 22 completed on fog_3 at time 17.276445000000045
# Task ID00038 of workflow 8 completed on fog_6 at time 17.279572500000043
# Task ID00081 of workflow 22 completed on server_2 at time 17.282113333333378
# Task ID00082 of workflow 22 completed on fog_3 at time 17.282415833333378
# Task ID00034 of workflow 73 completed on iot_6 at time 17.284803333333354
# Task ID00035 of workflow 73 completed on fog_7 at time 17.285053333333355
# Task ID00050 of workflow 31 completed on iot_6 at time 17.286283333333355
# Task ID00046 of workflow 34 completed on iot_6 at time 17.287603333333355
# Task ID00084 of workflow 72 completed on iot_6 at time 17.289283333333355
# Task ID00039 of workflow 92 completed on iot_6 at time 17.290583333333355
# Task ID00036 of workflow 73 completed on server_3 at time 17.29152166666669
# Task ID00083 of workflow 22 completed on fog_4 at time 17.296965833333378
# Task ID00084 of workflow 22 completed on fog_6 at time 17.297175833333377
# Task ID00051 of workflow 31 completed on fog_2 at time 17.301370833333355
# Task ID00052 of workflow 31 completed on iot_7 at time 17.303970833333356
# Task ID00053 of workflow 31 completed on fog_1 at time 17.314155833333356
# Task ID00060 of workflow 63 completed on iot_2 at time 17.315460000000044
# Task ID00080 of workflow 0 completed on iot_2 at time 17.317460000000043
# Task ID00061 of workflow 63 completed on iot_7 at time 17.318160000000045
# Task ID00033 of workflow 97 completed on iot_4 at time 17.320935000000013
# Task ID00081 of workflow 0 completed on fog_3 at time 17.325962500000042
# Task ID00062 of workflow 63 completed on fog_2 at time 17.330647500000044
# Task ID00063 of workflow 63 completed on fog_1 at time 17.330977500000046
# Task ID00055 of workflow 27 completed on iot_8 at time 17.340040000000045
# Task ID00085 of workflow 22 completed on fog_5 at time 17.340058333333378
# Task ID00054 of workflow 31 completed on fog_5 at time 17.34035083333338
# Task ID00056 of workflow 27 completed on fog_4 at time 17.340352500000044
# Task ID00064 of workflow 63 completed on fog_3 at time 17.345535000000044
# Task ID00065 of workflow 63 completed on server_3 at time 17.34577166666671
# Task ID00086 of workflow 22 completed on server_2 at time 17.349975000000043
# Task ID00087 of workflow 22 completed on fog_5 at time 17.350310000000043
# Task ID00066 of workflow 63 completed on fog_4 at time 17.35885166666671
# Task ID00067 of workflow 63 completed on server_2 at time 17.359010000000044
# Task ID00068 of workflow 63 completed on server_4 at time 17.36329833333338
# Task ID00069 of workflow 63 completed on server_1 at time 17.363465000000044
# Task ID00064 of workflow 26 completed on iot_3 at time 17.36487250000001
# Task ID00051 of workflow 96 completed on iot_5 at time 17.365118333333353
# Task ID00065 of workflow 26 completed on fog_4 at time 17.36522750000001
# Task ID00052 of workflow 95 completed on iot_3 at time 17.367472500000012
# Task ID00045 of workflow 78 completed on iot_2 at time 17.367720000000045
# Task ID00065 of workflow 7 completed on iot_5 at time 17.367958333333352
# Task ID00084 of workflow 30 completed on iot_3 at time 17.369152500000013
# Task ID00034 of workflow 81 completed on iot_6 at time 17.369863333333356
# Task ID00066 of workflow 7 completed on server_4 at time 17.376678333333352
# Task ID00067 of workflow 7 completed on server_2 at time 17.376836666666687
# Task ID00053 of workflow 95 completed on fog_4 at time 17.377657500000012
# Task ID00047 of workflow 59 completed on iot_8 at time 17.393280000000043
# Task ID00085 of workflow 30 completed on fog_2 at time 17.412035000000014
# Task ID00040 of workflow 92 completed on iot_6 at time 17.414323333333357
# Task ID00070 of workflow 63 completed on fog_7 at time 17.414410000000043
# Task ID00037 of workflow 73 completed on iot_6 at time 17.41662333333336
# Task ID00045 of workflow 6 completed on iot_5 at time 17.418218333333353
# Task ID00046 of workflow 6 completed on server_1 at time 17.418328333333353
# Task ID00054 of workflow 95 completed on iot_6 at time 17.41896333333336
# Task ID00047 of workflow 6 completed on server_0 at time 17.42276500000002
# Task ID00048 of workflow 6 completed on fog_2 at time 17.42300750000002
# Task ID00038 of workflow 73 completed on fog_7 at time 17.426435833333358
# Task ID00049 of workflow 6 completed on server_2 at time 17.429364166666684
# Task ID00064 of workflow 54 completed on iot_4 at time 17.437395000000013
# Task ID00065 of workflow 54 completed on fog_7 at time 17.437750000000012
# Task ID00052 of workflow 96 completed on iot_4 at time 17.439995000000014
# Task ID00044 of workflow 53 completed on iot_9 at time 17.44321500000001
# Task ID00048 of workflow 4 completed on iot_9 at time 17.44515500000001
# Task ID00087 of workflow 90 completed on iot_9 at time 17.447835000000012
# Task ID00066 of workflow 54 completed on fog_7 at time 17.45083000000001
# Task ID00066 of workflow 26 completed on iot_0 at time 17.46986750000001
# Task ID00067 of workflow 26 completed on fog_4 at time 17.47010500000001
# Task ID00035 of workflow 81 completed on iot_0 at time 17.47186750000001
# Task ID00077 of workflow 60 completed on iot_3 at time 17.472732500000014
# Task ID00036 of workflow 81 completed on server_0 at time 17.478335833333343
# Task ID00075 of workflow 2 completed on iot_8 at time 17.478380000000044
# Task ID00037 of workflow 81 completed on fog_2 at time 17.478623333333342
# Task ID00038 of workflow 81 completed on fog_6 at time 17.48843583333334
# Task ID00039 of workflow 81 completed on server_1 at time 17.488544166666674
# Task ID00055 of workflow 95 completed on iot_7 at time 17.48924333333336
# Task ID00056 of workflow 95 completed on fog_2 at time 17.48955583333336
# Task ID00068 of workflow 7 completed on iot_4 at time 17.491455000000013
# Task ID00069 of workflow 7 completed on fog_7 at time 17.491705000000014
# Task ID00040 of workflow 81 completed on fog_5 at time 17.494101666666673
# Task ID00047 of workflow 71 completed on iot_9 at time 17.50107500000001
# Task ID00049 of workflow 4 completed on iot_6 at time 17.52143500000001
# Task ID00050 of workflow 4 completed on fog_0 at time 17.52162000000001
# Task ID00078 of workflow 60 completed on iot_6 at time 17.52379500000001
# Task ID00076 of workflow 2 completed on iot_6 at time 17.52545500000001
# Task ID00071 of workflow 63 completed on iot_0 at time 17.53078750000001
# Task ID00057 of workflow 95 completed on fog_3 at time 17.532533333333358
# Task ID00041 of workflow 81 completed on iot_0 at time 17.53284750000001
# Task ID00077 of workflow 2 completed on server_4 at time 17.534086666666678
# Task ID00078 of workflow 2 completed on fog_2 at time 17.53438166666668
# Task ID00072 of workflow 63 completed on iot_0 at time 17.53548750000001
# Task ID00058 of workflow 95 completed on fog_3 at time 17.538105833333358
# Task ID00051 of workflow 11 completed on iot_5 at time 17.538918333333353
# Task ID00052 of workflow 11 completed on fog_1 at time 17.539243333333353
# Task ID00042 of workflow 81 completed on server_4 at time 17.53991500000001
# Task ID00080 of workflow 25 completed on iot_5 at time 17.54091833333335
# Task ID00079 of workflow 2 completed on server_1 at time 17.54311666666668
# Task ID00080 of workflow 2 completed on iot_0 at time 17.54511666666668
# Task ID00081 of workflow 25 completed on fog_3 at time 17.54942083333335
# Task ID00053 of workflow 11 completed on fog_6 at time 17.549428333333353
# Task ID00053 of workflow 9 completed on iot_3 at time 17.554212500000013
# Task ID00054 of workflow 9 completed on server_2 at time 17.554407500000014
# Task ID00054 of workflow 11 completed on iot_3 at time 17.556552500000013
# Task ID00075 of workflow 17 completed on iot_8 at time 17.563480000000045
# Task ID00076 of workflow 17 completed on server_4 at time 17.563618333333377
# Task ID00055 of workflow 11 completed on fog_5 at time 17.565337500000012
# Task ID00048 of workflow 35 completed on iot_8 at time 17.565420000000046
# Task ID00070 of workflow 1 completed on iot_1 at time 17.56589666666669
# Task ID00072 of workflow 83 completed on iot_8 at time 17.568060000000045
# Task ID00078 of workflow 68 completed on iot_1 at time 17.568256666666688
# Task ID00055 of workflow 29 completed on iot_9 at time 17.57135500000001
# Task ID00049 of workflow 35 completed on server_3 at time 17.57177666666671
# Task ID00050 of workflow 35 completed on fog_5 at time 17.57196166666671
# Task ID00071 of workflow 1 completed on fog_3 at time 17.57326166666669
# Task ID00072 of workflow 1 completed on server_2 at time 17.573481666666687
# Task ID00056 of workflow 29 completed on iot_0 at time 17.573855000000012
# Task ID00079 of workflow 68 completed on server_1 at time 17.57699166666669
# Task ID00073 of workflow 83 completed on fog_0 at time 17.579557500000046
# Task ID00074 of workflow 83 completed on fog_6 at time 17.579830000000047
# Task ID00040 of workflow 21 completed on iot_5 at time 17.585378333333352
# Task ID00041 of workflow 21 completed on fog_0 at time 17.585635833333352
# Task ID00035 of workflow 74 completed on iot_5 at time 17.58737833333335
# Task ID00036 of workflow 74 completed on server_3 at time 17.593846666666686
# Task ID00042 of workflow 21 completed on fog_1 at time 17.594378333333353
# Task ID00081 of workflow 2 completed on iot_7 at time 17.61313666666668
# Task ID00043 of workflow 21 completed on iot_7 at time 17.61583666666668
# Task ID00057 of workflow 29 completed on fog_4 at time 17.61683250000001
# Task ID00080 of workflow 68 completed on fog_4 at time 17.617082500000013
# Task ID00082 of workflow 2 completed on iot_7 at time 17.61825666666668
# Task ID00081 of workflow 68 completed on fog_2 at time 17.62558500000001
# Task ID00079 of workflow 60 completed on iot_4 at time 17.62861500000001
# Task ID00080 of workflow 60 completed on fog_5 at time 17.62886500000001
# Task ID00083 of workflow 2 completed on fog_4 at time 17.63280666666668
# Task ID00042 of workflow 67 completed on iot_1 at time 17.638196666666687
# Task ID00043 of workflow 67 completed on fog_1 at time 17.638534166666687
# Task ID00072 of workflow 69 completed on iot_1 at time 17.640836666666686
# Task ID00052 of workflow 39 completed on iot_1 at time 17.643436666666688
# Task ID00099 of workflow 61 completed on iot_1 at time 17.645496666666688
# Task ID00051 of workflow 4 completed on iot_6 at time 17.64615500000001
# Task ID00078 of workflow 5 completed on iot_1 at time 17.647856666666687
# Task ID00060 of workflow 58 completed on iot_8 at time 17.648100000000046
# Task ID00059 of workflow 52 completed on iot_8 at time 17.650020000000044
# Task ID00054 of workflow 48 completed on iot_1 at time 17.650196666666687
# Task ID00073 of workflow 69 completed on fog_5 at time 17.652334166666687
# Task ID00091 of workflow 38 completed on iot_8 at time 17.652360000000044
# Task ID00056 of workflow 19 completed on iot_1 at time 17.65269666666669
# Task ID00053 of workflow 39 completed on fog_0 at time 17.653621666666687
# Task ID00041 of workflow 13 completed on iot_1 at time 17.65475666666669
# Task ID00060 of workflow 52 completed on server_4 at time 17.656690000000044
# Task ID00069 of workflow 15 completed on iot_1 at time 17.656756666666688
# Task ID00050 of workflow 42 completed on iot_1 at time 17.65823666666669
# Task ID00039 of workflow 84 completed on iot_1 at time 17.65953666666669
# Task ID00042 of workflow 13 completed on server_2 at time 17.660585000000022
# Task ID00079 of workflow 5 completed on fog_1 at time 17.660959166666686
# Task ID00092 of workflow 38 completed on fog_2 at time 17.666320000000045
# Task ID00077 of workflow 17 completed on iot_3 at time 17.667198333333378
# Task ID00051 of workflow 42 completed on fog_6 at time 17.67332416666669
# Task ID00052 of workflow 42 completed on fog_1 at time 17.67364916666669
# Task ID00057 of workflow 19 completed on server_4 at time 17.68534166666671
# Task ID00058 of workflow 19 completed on server_3 at time 17.68905666666671
# Task ID00059 of workflow 19 completed on server_3 at time 17.68921666666671
# Task ID00070 of workflow 15 completed on server_1 at time 17.69072000000002
# Task ID00080 of workflow 5 completed on server_1 at time 17.690886666666685
# Task ID00071 of workflow 15 completed on server_1 at time 17.695796666666684
# Task ID00072 of workflow 15 completed on fog_1 at time 17.696126666666686
# Task ID00081 of workflow 60 completed on iot_0 at time 17.696885000000012
# Task ID00082 of workflow 60 completed on server_0 at time 17.697086666666678
# Task ID00060 of workflow 19 completed on fog_5 at time 17.69922166666671
# Task ID00052 of workflow 4 completed on iot_0 at time 17.699485000000013
# Task ID00054 of workflow 39 completed on iot_0 at time 17.701825000000014
# Task ID00064 of workflow 77 completed on iot_5 at time 17.70383833333335
# Task ID00065 of workflow 77 completed on fog_1 at time 17.70419333333335
# Task ID00059 of workflow 37 completed on iot_5 at time 17.70575833333335
# Task ID00039 of workflow 8 completed on iot_5 at time 17.70705833333335
# Task ID00073 of workflow 15 completed on fog_7 at time 17.707624166666687
# Task ID00074 of workflow 15 completed on fog_2 at time 17.707896666666688
# Task ID00053 of workflow 4 completed on fog_6 at time 17.709670000000013
# Task ID00055 of workflow 39 completed on fog_3 at time 17.710610000000013
# Task ID00056 of workflow 39 completed on fog_4 at time 17.710922500000013
# Task ID00057 of workflow 27 completed on iot_2 at time 17.711540000000046
# Task ID00058 of workflow 29 completed on iot_3 at time 17.711778333333378
# Task ID00059 of workflow 29 completed on fog_2 at time 17.71201833333338
# Task ID00046 of workflow 78 completed on iot_2 at time 17.712860000000045
# Task ID00084 of workflow 2 completed on iot_3 at time 17.713458333333378
# Task ID00078 of workflow 17 completed on iot_3 at time 17.715818333333377
# Task ID00066 of workflow 77 completed on fog_5 at time 17.71727333333335
# Task ID00060 of workflow 29 completed on server_4 at time 17.71868833333338
# Task ID00067 of workflow 77 completed on server_4 at time 17.718846666666714
# Task ID00055 of workflow 48 completed on iot_6 at time 17.720476666666688
# Task ID00073 of workflow 1 completed on iot_4 at time 17.72059500000001
# Task ID00056 of workflow 48 completed on server_3 at time 17.72068500000002
# Task ID00074 of workflow 69 completed on iot_6 at time 17.722656666666687
# Task ID00040 of workflow 8 completed on fog_5 at time 17.722830833333347
# Task ID00061 of workflow 58 completed on iot_4 at time 17.72329500000001
# Task ID00093 of workflow 38 completed on iot_6 at time 17.724056666666687
# Task ID00068 of workflow 77 completed on fog_4 at time 17.725279166666713
# Task ID00069 of workflow 77 completed on fog_2 at time 17.725529166666714
# Task ID00079 of workflow 17 completed on fog_1 at time 17.728920833333376
# Task ID00080 of workflow 17 completed on server_4 at time 17.72908750000004
# ...
# Task ID00000 of workflow 92 completed on iot_1 at time 32.28663666666672
# Task ID00001 of workflow 92 completed on fog_5 at time 32.28683666666672
# Workflow 92 is completed! Total completed workflows: 79
# Task ID00094 of workflow 62 completed on iot_0 at time 32.29856000000009
# Task ID00095 of workflow 62 completed on server_1 at time 32.29868333333342
# Task ID00070 of workflow 79 completed on iot_2 at time 32.305416666666716
# Task ID00087 of workflow 18 completed on iot_2 at time 32.308096666666714
# Task ID00091 of workflow 97 completed on iot_2 at time 32.31043666666671
# Task ID00092 of workflow 97 completed on fog_3 at time 32.32439666666671
# Task ID00093 of workflow 97 completed on server_0 at time 32.32451333333337
# Task ID00094 of workflow 97 completed on fog_5 at time 32.336633333333374
# Task ID00095 of workflow 97 completed on fog_4 at time 32.336818333333376
# Task ID00071 of workflow 79 completed on iot_3 at time 32.364336666666716
# Task ID00072 of workflow 79 completed on iot_7 at time 32.366976666666716
# Task ID00096 of workflow 6 completed on iot_1 at time 32.40043666666672
# Task ID00097 of workflow 6 completed on server_2 at time 32.400600000000054
# Task ID00086 of workflow 70 completed on iot_8 at time 32.40495666666672
# Task ID00087 of workflow 70 completed on fog_6 at time 32.40529166666672
# Task ID00098 of workflow 6 completed on fog_5 at time 32.41304250000005
# Task ID00099 of workflow 6 completed on server_0 at time 32.41321416666672
# Task ID00088 of workflow 70 completed on server_4 at time 32.41592500000005
# Task ID00089 of workflow 70 completed on fog_5 at time 32.41621500000005
# Task ID00090 of workflow 42 completed on iot_0 at time 32.42564000000009
# Task ID00091 of workflow 42 completed on iot_7 at time 32.42798000000008
# Task ID00087 of workflow 40 completed on iot_0 at time 32.428320000000085
# Task ID00086 of workflow 8 completed on iot_2 at time 32.42943666666671
# Task ID00001 of workflow 71 completed on iot_2 at time 32.431036666666714
# Workflow 71 is completed! Total completed workflows: 80
# Task ID00087 of workflow 8 completed on iot_5 at time 32.43211666666671
# Task ID00097 of workflow 84 completed on iot_2 at time 32.43299666666671
# Task ID00000 of workflow 66 completed on iot_2 at time 32.43367666666671
# Task ID00001 of workflow 66 completed on fog_5 at time 32.43387666666671
# Workflow 66 is completed! Total completed workflows: 81
# Task ID00098 of workflow 84 completed on fog_6 at time 32.44543916666671
# Task ID00099 of workflow 84 completed on fog_1 at time 32.445696666666706
# Task ID00088 of workflow 8 completed on fog_4 at time 32.448066666666705
# Task ID00089 of workflow 8 completed on server_2 at time 32.44826000000004
# Task ID00090 of workflow 8 completed on fog_7 at time 32.46414500000004
# Task ID00091 of workflow 8 completed on fog_1 at time 32.46443750000004
# Task ID00092 of workflow 8 completed on server_3 at time 32.473744166666705
# Task ID00088 of workflow 18 completed on iot_3 at time 32.49193666666672
# Task ID00089 of workflow 18 completed on fog_3 at time 32.49222666666672
# Task ID00090 of workflow 18 completed on server_3 at time 32.50281666666672
# Task ID00091 of workflow 18 completed on server_3 at time 32.503011666666715
# Task ID00092 of workflow 18 completed on fog_3 at time 32.51697166666671
# Task ID00093 of workflow 18 completed on iot_7 at time 32.51837166666671
# Task ID00094 of workflow 91 completed on iot_0 at time 32.52528000000009
# Task ID00095 of workflow 91 completed on fog_6 at time 32.52546500000009
# Task ID00095 of workflow 82 completed on iot_0 at time 32.52676000000009
# Task ID00087 of workflow 81 completed on iot_0 at time 32.529440000000086
# Task ID00094 of workflow 18 completed on fog_7 at time 32.53049166666671
# Task ID00099 of workflow 32 completed on iot_0 at time 32.53150000000009
# Task ID00000 of workflow 65 completed on iot_0 at time 32.53218000000009
# Task ID00000 of workflow 32 completed on iot_8 at time 32.53218000000009
# Task ID00001 of workflow 32 completed on iot_9 at time 32.53378000000009
# Workflow 32 is completed! Total completed workflows: 82
# Task ID00096 of workflow 82 completed on server_3 at time 32.536243333333424
# Task ID00095 of workflow 18 completed on server_3 at time 32.53636666666676
# Task ID00097 of workflow 82 completed on fog_1 at time 32.53648833333342
# Task ID00001 of workflow 65 completed on server_3 at time 32.53650000000009
# Workflow 65 is completed! Total completed workflows: 83
# Task ID00092 of workflow 42 completed on iot_1 at time 32.53966000000008
# Task ID00096 of workflow 91 completed on fog_3 at time 32.53969000000009
# Task ID00097 of workflow 91 completed on fog_7 at time 32.53993500000009
# Task ID00088 of workflow 81 completed on server_0 at time 32.54007333333342
# Task ID00000 of workflow 84 completed on iot_1 at time 32.540340000000086
# Task ID00089 of workflow 81 completed on fog_3 at time 32.54036333333342
# Task ID00001 of workflow 84 completed on fog_5 at time 32.540540000000085
# Workflow 84 is completed! Total completed workflows: 84
# Task ID00093 of workflow 42 completed on iot_8 at time 32.54106000000008
# Task ID00090 of workflow 70 completed on iot_6 at time 32.54329500000005
# Task ID00091 of workflow 70 completed on server_3 at time 32.54349000000005
# Task ID00093 of workflow 8 completed on iot_6 at time 32.54469500000005
# Task ID00098 of workflow 91 completed on server_2 at time 32.54823000000009
# Task ID00090 of workflow 81 completed on server_4 at time 32.55095333333342
# Task ID00091 of workflow 81 completed on fog_7 at time 32.55124583333342
# Task ID00094 of workflow 42 completed on fog_0 at time 32.55318000000008
# Task ID00095 of workflow 42 completed on fog_6 at time 32.553365000000085
# Task ID00099 of workflow 91 completed on fog_0 at time 32.55343750000008
# Task ID00000 of workflow 91 completed on iot_5 at time 32.55411750000008
# Task ID00001 of workflow 91 completed on fog_1 at time 32.55431750000008
# Workflow 91 is completed! Total completed workflows: 85
# Task ID00088 of workflow 40 completed on iot_4 at time 32.555920000000086
# Task ID00089 of workflow 40 completed on server_0 at time 32.55611333333342
# Task ID00094 of workflow 8 completed on server_2 at time 32.55631000000009
# Task ID00092 of workflow 70 completed on fog_4 at time 32.557450000000046
# Task ID00093 of workflow 70 completed on server_3 at time 32.55756666666671
# Task ID00092 of workflow 81 completed on server_1 at time 32.560552500000085
# Task ID00093 of workflow 81 completed on fog_4 at time 32.560727500000084
# Task ID00090 of workflow 51 completed on iot_2 at time 32.56075666666671
# Task ID00091 of workflow 51 completed on fog_6 at time 32.56104916666671
# Task ID00097 of workflow 74 completed on iot_2 at time 32.56271666666671
# Task ID00000 of workflow 6 completed on iot_2 at time 32.56339666666671
# Task ID00090 of workflow 40 completed on server_0 at time 32.56670333333342
# Task ID00001 of workflow 6 completed on server_0 at time 32.56683666666675
# Workflow 6 is completed! Total completed workflows: 86
# Task ID00091 of workflow 40 completed on iot_5 at time 32.56904333333342
# Task ID00094 of workflow 70 completed on fog_5 at time 32.56968666666671
# Task ID00095 of workflow 70 completed on fog_4 at time 32.569871666666714
# Task ID00092 of workflow 40 completed on fog_2 at time 32.583003333333416
# Task ID00096 of workflow 70 completed on fog_3 at time 32.58409666666672
# Task ID00097 of workflow 70 completed on server_3 at time 32.58426000000005
# Task ID00098 of workflow 70 completed on server_3 at time 32.59255500000005
# Task ID00099 of workflow 70 completed on fog_6 at time 32.59281250000004
# Task ID00000 of workflow 70 completed on fog_6 at time 32.59289750000004
# Task ID00001 of workflow 70 completed on iot_8 at time 32.594497500000045
# Workflow 70 is completed! Total completed workflows: 87
# Task ID00096 of workflow 97 completed on iot_3 at time 32.605736666666715
# Task ID00097 of workflow 97 completed on iot_9 at time 32.60769666666671
# Task ID00098 of workflow 97 completed on server_0 at time 32.61599166666671
# Task ID00098 of workflow 41 completed on iot_0 at time 32.63172000000009
# Task ID00099 of workflow 41 completed on fog_0 at time 32.63197750000008
# Task ID00000 of workflow 41 completed on iot_5 at time 32.632657500000086
# Task ID00099 of workflow 87 completed on iot_0 at time 32.63378000000009
# Task ID00000 of workflow 87 completed on fog_1 at time 32.633865000000085
# Task ID00001 of workflow 41 completed on iot_5 at time 32.63425750000009
# Workflow 41 is completed! Total completed workflows: 88
# Task ID00001 of workflow 87 completed on iot_2 at time 32.63546500000009
# Workflow 87 is completed! Total completed workflows: 89
# Task ID00094 of workflow 81 completed on iot_7 at time 32.65768750000009
# Task ID00093 of workflow 40 completed on iot_7 at time 32.65908750000008
# Task ID00098 of workflow 74 completed on iot_1 at time 32.66225666666671
# Task ID00099 of workflow 74 completed on fog_4 at time 32.6625141666667
# Task ID00000 of workflow 74 completed on server_4 at time 32.66257083333337
# Task ID00001 of workflow 74 completed on iot_5 at time 32.66417083333337
# Workflow 74 is completed! Total completed workflows: 90
# Task ID00096 of workflow 42 completed on iot_6 at time 32.66716500000008
# Task ID00095 of workflow 81 completed on iot_6 at time 32.66864500000008
# Task ID00097 of workflow 42 completed on iot_5 at time 32.66912500000008
# Task ID00094 of workflow 40 completed on fog_3 at time 32.67120750000009
# Task ID00095 of workflow 40 completed on server_4 at time 32.67133083333342
# Task ID00096 of workflow 81 completed on fog_0 at time 32.68287000000009
# Task ID00097 of workflow 81 completed on server_1 at time 32.68303333333342
# Task ID00096 of workflow 40 completed on fog_3 at time 32.685555833333424
# Task ID00097 of workflow 40 completed on server_3 at time 32.68571916666676
# Task ID00098 of workflow 40 completed on fog_7 at time 32.698161666666756
# Task ID00096 of workflow 18 completed on iot_3 at time 32.71953666666671
# Task ID00097 of workflow 18 completed on server_4 at time 32.719700000000046
# Task ID00098 of workflow 18 completed on fog_3 at time 32.732142500000045
# Task ID00099 of workflow 18 completed on server_3 at time 32.73231416666671
# Task ID00000 of workflow 18 completed on iot_8 at time 32.732994166666714
# Task ID00001 of workflow 18 completed on fog_5 at time 32.73319416666671
# Workflow 18 is completed! Total completed workflows: 91
# Task ID00096 of workflow 62 completed on iot_0 at time 32.747580000000085
# Task ID00097 of workflow 62 completed on fog_1 at time 32.747825000000084
# Task ID00098 of workflow 62 completed on fog_1 at time 32.76026750000008
# Task ID00099 of workflow 62 completed on fog_5 at time 32.76052500000008
# Task ID00000 of workflow 62 completed on server_0 at time 32.760581666666745
# Task ID00001 of workflow 62 completed on fog_3 at time 32.760781666666745
# Workflow 62 is completed! Total completed workflows: 92
# Task ID00098 of workflow 81 completed on iot_4 at time 32.78257333333342
# Task ID00099 of workflow 81 completed on server_2 at time 32.782745000000084
# Task ID00000 of workflow 81 completed on fog_1 at time 32.78283000000008
# Task ID00001 of workflow 81 completed on iot_2 at time 32.784430000000086
# Workflow 81 is completed! Total completed workflows: 93
# Task ID00098 of workflow 82 completed on iot_3 at time 32.81907666666671
# Task ID00095 of workflow 8 completed on iot_3 at time 32.82055666666671
# Task ID00096 of workflow 8 completed on fog_7 at time 32.834781666666714
# Task ID00097 of workflow 8 completed on server_1 at time 32.83494500000005
# Task ID00073 of workflow 79 completed on iot_0 at time 32.839560000000084
# Task ID00074 of workflow 79 completed on fog_6 at time 32.839832500000085
# Task ID00098 of workflow 42 completed on iot_3 at time 32.92009666666671
# Task ID00099 of workflow 42 completed on server_2 at time 32.920268333333375
# Task ID00099 of workflow 40 completed on iot_3 at time 32.92215666666671
# Task ID00000 of workflow 40 completed on fog_2 at time 32.92224166666671
# Task ID00099 of workflow 82 completed on iot_3 at time 32.92421666666671
# Task ID00001 of workflow 40 completed on iot_3 at time 32.92581666666671
# Workflow 40 is completed! Total completed workflows: 94
# Task ID00000 of workflow 82 completed on iot_3 at time 32.926496666666715
# Task ID00001 of workflow 82 completed on fog_0 at time 32.926696666666714
# Workflow 82 is completed! Total completed workflows: 95
# Task ID00098 of workflow 8 completed on iot_9 at time 32.934485000000045
# Task ID00099 of workflow 8 completed on iot_1 at time 32.936545000000045
# Task ID00000 of workflow 8 completed on iot_8 at time 32.93722500000005
# Task ID00001 of workflow 8 completed on fog_7 at time 32.93742500000005
# Workflow 8 is completed! Total completed workflows: 96
# Task ID00092 of workflow 51 completed on iot_0 at time 32.951240000000084
# Task ID00093 of workflow 51 completed on fog_1 at time 32.95141500000008
# Task ID00099 of workflow 97 completed on iot_0 at time 32.953300000000084
# Task ID00075 of workflow 79 completed on iot_0 at time 33.03840000000008
# Task ID00076 of workflow 79 completed on server_2 at time 33.03853833333341
# Task ID00000 of workflow 42 completed on iot_0 at time 33.039080000000084
# Task ID00094 of workflow 51 completed on iot_9 at time 33.048375000000085
# Task ID00000 of workflow 97 completed on iot_9 at time 33.04905500000009
# Task ID00001 of workflow 97 completed on fog_5 at time 33.04925500000009
# Workflow 97 is completed! Total completed workflows: 97
# Task ID00095 of workflow 51 completed on iot_0 at time 33.049855000000086
# Task ID00077 of workflow 79 completed on fog_6 at time 33.051485833333416
# Task ID00001 of workflow 42 completed on fog_6 at time 33.051685833333416
# Workflow 42 is completed! Total completed workflows: 98
# Task ID00078 of workflow 79 completed on iot_1 at time 33.05384583333342
# Task ID00079 of workflow 79 completed on fog_4 at time 33.06694833333342
# Task ID00080 of workflow 79 completed on fog_0 at time 33.06719833333342
# Task ID00081 of workflow 79 completed on server_0 at time 33.072866666666755
# Task ID00082 of workflow 79 completed on server_2 at time 33.073068333333424
# Task ID00096 of workflow 51 completed on iot_4 at time 33.163655000000084
# Task ID00097 of workflow 51 completed on iot_1 at time 33.16561500000008
# Task ID00098 of workflow 51 completed on server_0 at time 33.17391000000008
# Task ID00099 of workflow 51 completed on iot_9 at time 33.17597000000008
# Task ID00000 of workflow 51 completed on fog_4 at time 33.176055000000076
# Task ID00001 of workflow 51 completed on fog_7 at time 33.176255000000076
# Workflow 51 is completed! Total completed workflows: 99
# Task ID00083 of workflow 79 completed on iot_5 at time 33.18946833333342
# Task ID00084 of workflow 79 completed on fog_2 at time 33.189678333333426
# Task ID00085 of workflow 79 completed on iot_9 at time 33.53273833333343
# Task ID00086 of workflow 79 completed on iot_4 at time 33.65173833333343
# Task ID00087 of workflow 79 completed on fog_2 at time 33.652073333333426
# Task ID00088 of workflow 79 completed on server_0 at time 33.66270666666676
# Task ID00089 of workflow 79 completed on fog_7 at time 33.66299666666676
# Task ID00090 of workflow 79 completed on iot_4 at time 33.79007666666676
# Task ID00091 of workflow 79 completed on iot_8 at time 33.79241666666675
# Task ID00092 of workflow 79 completed on iot_1 at time 33.90409666666675
# Task ID00093 of workflow 79 completed on iot_1 at time 33.90549666666675
# Task ID00094 of workflow 79 completed on server_4 at time 33.91357666666675
# Task ID00095 of workflow 79 completed on fog_0 at time 33.91376166666675
# Task ID00096 of workflow 79 completed on iot_5 at time 34.02756166666675
# Task ID00097 of workflow 79 completed on fog_4 at time 34.02780666666675
# Task ID00098 of workflow 79 completed on fog_3 at time 34.04024916666675
# Task ID00099 of workflow 79 completed on fog_0 at time 34.040506666666744
# Task ID00000 of workflow 79 completed on iot_0 at time 34.041186666666746
# Task ID00001 of workflow 79 completed on fog_4 at time 34.041386666666746
# Workflow 79 is completed! Total completed workflows: 100
