# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahra-FallahMMA/DRL_Offload_Allocation/blob/main/Random_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import Libraries

# %%
import xml.etree.ElementTree as ET
from io import StringIO
import os
import re
import numpy as np
from collections import deque, defaultdict
import random
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.models import load_model
from itertools import product
import tensorflow as tf
# !pip install simpy
import simpy

# Set TensorFlow logging level to suppress detailed logs
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.get_logger().setLevel('ERROR')
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %% [markdown]
# # class RandomAgent

# %%
class RandomAgent:

  def __init__(self, action_size):
      self.action_size = action_size

  def choose_action(self):
        return random.randrange(self.action_size)

# %% [markdown]
# # class Task

# %%
class Task:
    def __init__(self, id, instructions, workflow_id):
        self.id = id
        self.instructions = instructions  # Execution time or computational instructions
        self.children = []  # List of tasks that depend on this task
        self.parents = []  # List of tasks this task depends on
        self.executed = False  # Status of execution
        self.executed_on = None  # Node this task was executed on
        self.execution_time = 0  # Time taken to execute the task
        self.cost = 0  # Cost of executing the task
        self.comm_delay = 0  # Communication delay in seconds
        self.workflow_id = workflow_id  # Workflow identifier to which this task belongs

# %% [markdown]
# # class Workflow

# %%
class Workflow:
    def __init__(self, id):
        self.id = id  # Workflow identifier
        self.tasks = {}  # Dictionary of tasks in the workflow

    def add_task(self, task_id, instructions, parent_ids=[]):
        if task_id not in self.tasks:
            self.tasks[task_id] = Task(task_id, instructions, self.id)
        task = self.tasks[task_id]
        for parent_id in parent_ids:
            if parent_id not in self.tasks:
                self.tasks[parent_id] = Task(parent_id, 0, self.id)
            parent_task = self.tasks[parent_id]
            parent_task.children.append(task)
            task.parents.append(parent_task)

# %% [markdown]
# # class parse_dax

# %%
def parse_dax(file_path, workflow_id):
    tree = ET.parse(file_path)
    root = tree.getroot()

    workflow_id = workflow_id
    workflow = Workflow(workflow_id)

    # Parse jobs
    jobs = {job.attrib['id']: job for job in root.findall('{http://pegasus.isi.edu/schema/DAX}job')}

    # Add jobs to workflow
    for job_id, job in jobs.items():
        instructions = float(job.attrib.get('runtime', 0))
        workflow.add_task(job_id, instructions)

    # Parse dependencies
    for child in root.findall('{http://pegasus.isi.edu/schema/DAX}child'):
        child_id = child.attrib['ref']
        parent_ids = [parent.attrib['ref'] for parent in child.findall('{http://pegasus.isi.edu/schema/DAX}parent')]
        workflow.add_task(child_id, 0, parent_ids)  # Adds a child node with its parent nodes, setting instructions to 0 to avoid overwrite

    return workflow


def ensemble_of_workflows(name, size=10, distribution='constant', dax_path=''):
    ws = []
    ensemble = []
    directory_path = dax_path  # Directory containing DAX files

    # List and filter files in directory
    files = os.listdir(directory_path)
    filtered_files = [file for file in files if name in file]

    if distribution == 'constant':
        pattern = r'100(?!\d)'
        for s in filtered_files:
            if re.search(pattern, s):
                ensemble = [s] * size  # Replicate the matched file 'size' times
                break
    else:
        numbers = np.random.randint(0, len(filtered_files), size)
        ensemble = [filtered_files[i] for i in numbers]  # Select random files based on uniform distribution
    w_id = 0
    for name in ensemble:
        ws.append(parse_dax(dax_path+name,w_id))
        w_id = w_id + 1

    return ws

# %% [markdown]
# # Loading dax_file

# %%
from google.colab import drive
import glob

drive.mount('/content/drive')
folder_path = '/content/drive/My Drive/Zahra/dax/'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # class Device

# %%
class Device:
    def __init__(self, id, mips, cost_per_hour, env):
        self.id = id
        self.mips = mips
        self.cost_per_hour = cost_per_hour
        self.queue = deque()
        self.runnig_queue = deque()
        self.resource = simpy.Resource(env, capacity=1)

    def add_task_to_queue(self, task):
        self.queue.append(task)

    def get_next_task(self):
        return self.queue.popleft() if self.queue else None

    def waiting_time(self):
        waiting_time = 0
        for t in self.queue:
            waiting_time += t.instructions / self.mips
        return waiting_time

# %% [markdown]
# # class FogEnv

# %%
import simpy

class FogEnv:
    def __init__(self, env, iot_devices, fog_nodes, cloud_servers, workflows):
        self.env = env
        self.iot_devices = iot_devices
        self.fog_nodes = fog_nodes
        self.cloud_servers = cloud_servers
        self.cost = 0
        self.completed_workflows = 0
        self.workflows = workflows

    def assign_task(self, task, device):
        with device.resource.request() as req:
            yield req
            instructions = task.instructions
            execution_time = instructions / device.mips
            yield self.env.timeout(execution_time)
            self.cost += execution_time * device.cost_per_hour
            task.executed = True
            task.execution_time = execution_time
            device.queue.popleft()
            print(f"Task {task.id} of workflow {task.workflow_id} completed on {device.id} at time {self.env.now}")

            # Check if the workflow is completed
            workflow = next(wf for wf in self.workflows if wf.id == task.workflow_id)
            self.check_workflow_completion(workflow)


    def get_device_by_id(self, device_id):
        for device in self.iot_devices + self.fog_nodes + self.cloud_servers:
            if device.id == device_id:
                return device
        return None

    def check_workflow_completion(self, workflow):
        # Check if all tasks in the workflow are executed
        if all(task.executed for task in workflow.tasks.values()):
            self.completed_workflows += 1  # Increment completed workflows counter
            print(f"Workflow {workflow.id} is completed! Total completed workflows: {self.completed_workflows}")





def process_workflow(env, workflow, fog_env, agent):
      while(True):
        if all([task.executed for task in workflow.tasks.values()]):
          break
        for task in workflow.tasks.values():
            if task.executed:
              continue
            if all([parent.executed for parent in task.parents]) or task.parents == []:
                action = agent.choose_action()
                devices = fog_env.iot_devices + fog_env.fog_nodes + fog_env.cloud_servers
                device = devices[action]
                device.add_task_to_queue(task)
                yield env.process(fog_env.assign_task(task, device))

# %% [markdown]
# # class NewSim

# %%
class  NewSim:
    def __init__(self, num_iot, num_fog, num_server):
        self.num_iot = num_iot
        self.num_fog = num_fog
        self.num_server = num_server
        self.num_totla_dev = num_iot + num_fog + num_server
        self.env = simpy.Environment()
        self.reset()
        self.run()

    def reset(self):
        self.iot_devices = [Device(f'iot_{i}', 500, 0, self.env) for i in range(self.num_iot)]
        self.fog_devices = [Device(f'fog_{i}', 4000, 1, self.env) for i in range(self.num_fog)]
        self.server_devices = [Device(f'server_{i}', 6000, 8, self.env) for i in range(self.num_server)]
        self.agent = RandomAgent(action_size=self.num_totla_dev)
        self.workflows = ensemble_of_workflows(name = 'CyberShake', size=100, distribution = 'constant', dax_path="/content/drive/My Drive/Zahra/dax/")

    def run(self):
        self.fog_env = FogEnv(self.env, self.iot_devices, self.fog_devices, self.server_devices,self.workflows)
        for workflow in self.workflows:
                self.env.process(process_workflow(self.env, workflow, self.fog_env, self.agent))

        self.env.run()  # Run simulation for a time period

# %% [markdown]
# # run simulation

# %%
simulation = NewSim(num_iot=10, num_fog=8, num_server=5)
print(simulation.fog_env.cost)
# Out:
# Streaming output truncated to the last 5000 lines.
# Task ID00042 of workflow 71 completed on fog_2 at time 14.889251666666679
# Task ID00053 of workflow 36 completed on fog_6 at time 14.890300000000016
# Task ID00057 of workflow 35 completed on iot_8 at time 14.898735833333362
# Task ID00059 of workflow 26 completed on iot_8 at time 14.900655833333362
# Task ID00058 of workflow 35 completed on fog_2 at time 14.904308333333361
# Task ID00059 of workflow 35 completed on fog_7 at time 14.904548333333361
# Task ID00036 of workflow 53 completed on iot_5 at time 14.908690000000016
# Task ID00046 of workflow 99 completed on iot_5 at time 14.910010000000016
# Task ID00048 of workflow 10 completed on iot_5 at time 14.911950000000015
# Task ID00060 of workflow 35 completed on fog_0 at time 14.91455333333336
# Task ID00055 of workflow 83 completed on iot_1 at time 14.926395833333366
# Task ID00069 of workflow 98 completed on iot_1 at time 14.928395833333367
# Task ID00061 of workflow 67 completed on iot_1 at time 14.931095833333368
# Task ID00062 of workflow 68 completed on iot_2 at time 14.932840000000024
# Task ID00061 of workflow 39 completed on iot_1 at time 14.933795833333368
# Task ID00079 of workflow 64 completed on iot_6 at time 14.937760000000024
# Task ID00080 of workflow 64 completed on fog_4 at time 14.938010000000023
# Task ID00062 of workflow 39 completed on server_3 at time 14.942120833333368
# Task ID00062 of workflow 67 completed on fog_7 at time 14.943583333333368
# Task ID00063 of workflow 67 completed on server_2 at time 14.943803333333369
# Task ID00081 of workflow 64 completed on fog_1 at time 14.946512500000024
# Task ID00082 of workflow 64 completed on fog_6 at time 14.946815000000024
# Task ID00066 of workflow 88 completed on iot_4 at time 14.951848333333356
# Task ID00039 of workflow 95 completed on iot_4 at time 14.953148333333356
# Task ID00064 of workflow 67 completed on server_0 at time 14.95350833333337
# Task ID00065 of workflow 67 completed on fog_1 at time 14.95386333333337
# Task ID00040 of workflow 95 completed on server_2 at time 14.956853333333356
# Task ID00036 of workflow 19 completed on iot_9 at time 14.957957500000012
# Task ID00083 of workflow 64 completed on fog_2 at time 14.961365000000024
# Task ID00084 of workflow 64 completed on server_4 at time 14.961505000000024
# Task ID00066 of workflow 67 completed on server_1 at time 14.96258333333337
# Task ID00067 of workflow 67 completed on fog_6 at time 14.962820833333371
# Task ID00083 of workflow 22 completed on iot_7 at time 14.969305000000022
# Task ID00056 of workflow 16 completed on iot_7 at time 14.971805000000021
# Task ID00046 of workflow 2 completed on iot_7 at time 14.973125000000021
# Task ID00047 of workflow 2 completed on fog_5 at time 14.979780000000021
# Task ID00048 of workflow 2 completed on fog_4 at time 14.980022500000022
# Task ID00042 of workflow 89 completed on iot_5 at time 14.981890000000016
# Task ID00043 of workflow 89 completed on fog_7 at time 14.982227500000016
# Task ID00035 of workflow 14 completed on iot_5 at time 14.983890000000017
# Task ID00041 of workflow 69 completed on iot_5 at time 14.985950000000017
# Task ID00036 of workflow 14 completed on server_1 at time 14.99035833333335
# Task ID00047 of workflow 82 completed on iot_6 at time 14.991000000000025
# Task ID00048 of workflow 82 completed on server_2 at time 14.991161666666692
# Task ID00042 of workflow 69 completed on server_4 at time 14.99177833333335
# Task ID00043 of workflow 69 completed on server_2 at time 14.99200333333335
# Task ID00049 of workflow 82 completed on server_1 at time 14.997518333333359
# Task ID00050 of workflow 82 completed on fog_7 at time 14.997703333333359
# Task ID00040 of workflow 25 completed on iot_9 at time 15.002417500000012
# Task ID00041 of workflow 25 completed on server_3 at time 15.002589166666679
# Task ID00057 of workflow 16 completed on fog_0 at time 15.01478250000002
# Task ID00058 of workflow 16 completed on fog_1 at time 15.02035500000002
# Task ID00059 of workflow 16 completed on fog_3 at time 15.02059500000002
# Task ID00044 of workflow 89 completed on fog_6 at time 15.031985000000017
# Task ID00047 of workflow 5 completed on iot_5 at time 15.039190000000017
# Task ID00048 of workflow 5 completed on server_4 at time 15.039351666666684
# Task ID00060 of workflow 16 completed on fog_6 at time 15.041990000000016
# Task ID00047 of workflow 99 completed on iot_6 at time 15.044240000000025
# Task ID00048 of workflow 99 completed on fog_2 at time 15.044482500000026
# Task ID00063 of workflow 68 completed on iot_6 at time 15.046880000000025
# Task ID00067 of workflow 88 completed on iot_6 at time 15.048780000000024
# Task ID00064 of workflow 91 completed on iot_1 at time 15.050255833333368
# Task ID00065 of workflow 91 completed on fog_5 at time 15.05061083333337
# Task ID00036 of workflow 94 completed on iot_7 at time 15.05074500000002
# Task ID00037 of workflow 94 completed on fog_6 at time 15.051032500000021
# Task ID00068 of workflow 88 completed on server_0 at time 15.053068333333357
# Task ID00069 of workflow 88 completed on fog_3 at time 15.053318333333356
# Task ID00051 of workflow 61 completed on iot_2 at time 15.053540000000023
# Task ID00052 of workflow 61 completed on iot_6 at time 15.056140000000022
# Task ID00066 of workflow 79 completed on iot_4 at time 15.057788333333356
# Task ID00038 of workflow 94 completed on fog_6 at time 15.060845000000022
# Task ID00057 of workflow 48 completed on iot_3 at time 15.061285833333354
# Task ID00052 of workflow 44 completed on iot_3 at time 15.063885833333353
# Task ID00037 of workflow 53 completed on iot_3 at time 15.066185833333353
# Task ID00038 of workflow 53 completed on server_1 at time 15.07272750000002
# Task ID00039 of workflow 53 completed on server_3 at time 15.072835833333354
# Task ID00040 of workflow 53 completed on fog_4 at time 15.078393333333354
# Task ID00041 of workflow 53 completed on server_0 at time 15.07856500000002
# Task ID00038 of workflow 12 completed on iot_9 at time 15.080917500000012
# Task ID00039 of workflow 12 completed on fog_3 at time 15.081080000000012
# Task ID00057 of workflow 6 completed on iot_0 at time 15.083700000000022
# Task ID00056 of workflow 29 completed on iot_0 at time 15.086200000000021
# Task ID00040 of workflow 12 completed on fog_4 at time 15.086637500000013
# Task ID00050 of workflow 80 completed on iot_0 at time 15.087680000000022
# Task ID00045 of workflow 86 completed on iot_5 at time 15.089450000000017
# Task ID00067 of workflow 23 completed on iot_5 at time 15.091350000000016
# Task ID00040 of workflow 60 completed on iot_1 at time 15.09471583333337
# Task ID00058 of workflow 77 completed on iot_7 at time 15.09532500000002
# Task ID00059 of workflow 54 completed on iot_1 at time 15.09663583333337
# Task ID00051 of workflow 80 completed on server_4 at time 15.097738333333355
# Task ID00068 of workflow 23 completed on fog_5 at time 15.097782500000017
# Task ID00069 of workflow 23 completed on fog_4 at time 15.098032500000016
# Task ID00052 of workflow 80 completed on fog_2 at time 15.098063333333355
# Task ID00060 of workflow 54 completed on server_2 at time 15.10330583333337
# Task ID00070 of workflow 88 completed on fog_7 at time 15.104263333333357
# Task ID00053 of workflow 80 completed on fog_7 at time 15.114448333333357
# Task ID00061 of workflow 54 completed on fog_7 at time 15.114785833333357
# Task ID00054 of workflow 80 completed on fog_7 at time 15.115078333333358
# Task ID00057 of workflow 29 completed on fog_3 at time 15.12917750000002
# Task ID00049 of workflow 10 completed on iot_2 at time 15.129820000000024
# Task ID00050 of workflow 10 completed on server_2 at time 15.129943333333356
# Task ID00058 of workflow 29 completed on fog_3 at time 15.13475000000002
# Task ID00059 of workflow 29 completed on server_1 at time 15.13491000000002
# Task ID00047 of workflow 75 completed on iot_0 at time 15.140920000000023
# Task ID00048 of workflow 75 completed on server_4 at time 15.14108166666669
# Task ID00060 of workflow 29 completed on server_1 at time 15.141580000000019
# Task ID00061 of workflow 29 completed on server_1 at time 15.14180500000002
# Task ID00047 of workflow 43 completed on iot_1 at time 15.14987583333337
# Task ID00062 of workflow 29 completed on server_1 at time 15.150130000000019
# Task ID00053 of workflow 33 completed on iot_9 at time 15.162397500000013
# Task ID00056 of workflow 57 completed on iot_9 at time 15.164897500000013
# Task ID00074 of workflow 38 completed on iot_9 at time 15.167077500000012
# Task ID00075 of workflow 38 completed on fog_3 at time 15.177715000000012
# Task ID00076 of workflow 38 completed on fog_2 at time 15.177922500000012
# Task ID00064 of workflow 68 completed on iot_3 at time 15.182645833333353
# Task ID00065 of workflow 68 completed on fog_4 at time 15.183000833333354
# Task ID00077 of workflow 38 completed on server_1 at time 15.186554166666678
# Task ID00066 of workflow 68 completed on server_0 at time 15.191720833333354
# Task ID00057 of workflow 57 completed on fog_5 at time 15.207875000000012
# Task ID00042 of workflow 59 completed on iot_0 at time 15.210860000000023
# Task ID00053 of workflow 61 completed on iot_2 at time 15.211300000000024
# Task ID00058 of workflow 57 completed on server_1 at time 15.211590000000012
# Task ID00059 of workflow 57 completed on server_0 at time 15.211750000000011
# Task ID00054 of workflow 61 completed on server_1 at time 15.211785000000011
# Task ID00051 of workflow 73 completed on iot_5 at time 15.212050000000016
# Task ID00050 of workflow 45 completed on iot_0 at time 15.212340000000024
# Task ID00065 of workflow 58 completed on iot_0 at time 15.215180000000025
# Task ID00051 of workflow 34 completed on iot_7 at time 15.21602500000002
# Task ID00052 of workflow 34 completed on fog_6 at time 15.21635000000002
# Task ID00055 of workflow 51 completed on iot_1 at time 15.22015583333337
# Task ID00056 of workflow 51 completed on fog_6 at time 15.22046833333337
# Task ID00053 of workflow 34 completed on server_1 at time 15.22314000000002
# Task ID00066 of workflow 58 completed on server_3 at time 15.223900000000025
# Task ID00058 of workflow 48 completed on iot_3 at time 15.227225833333353
# Task ID00059 of workflow 48 completed on server_2 at time 15.227385833333352
# Task ID00078 of workflow 38 completed on iot_3 at time 15.229585833333353
# Task ID00060 of workflow 48 completed on fog_3 at time 15.237390833333352
# Task ID00079 of workflow 38 completed on server_0 at time 15.238320833333352
# Task ID00080 of workflow 38 completed on iot_6 at time 15.240320833333353
# Task ID00057 of workflow 87 completed on iot_8 at time 15.244475833333361
# Task ID00057 of workflow 51 completed on server_1 at time 15.251791666666687
# Task ID00047 of workflow 20 completed on iot_0 at time 15.268420000000026
# Task ID00048 of workflow 20 completed on fog_1 at time 15.268662500000026
# Task ID00045 of workflow 32 completed on iot_1 at time 15.27041583333337
# Task ID00049 of workflow 20 completed on fog_4 at time 15.278197500000026
# Task ID00046 of workflow 32 completed on fog_4 at time 15.278362500000027
# Task ID00042 of workflow 53 completed on iot_2 at time 15.281240000000025
# Task ID00062 of workflow 46 completed on iot_7 at time 15.31592500000002
# Task ID00063 of workflow 46 completed on fog_0 at time 15.31625500000002
# Task ID00054 of workflow 36 completed on iot_7 at time 15.31826500000002
# Task ID00053 of workflow 56 completed on iot_8 at time 15.325955833333362
# Task ID00064 of workflow 46 completed on server_0 at time 15.32596000000002
# Task ID00065 of workflow 46 completed on server_2 at time 15.326196666666686
# Task ID00054 of workflow 56 completed on fog_6 at time 15.326248333333362
# Task ID00064 of workflow 92 completed on iot_5 at time 15.328510000000016
# Task ID00063 of workflow 3 completed on iot_8 at time 15.328595833333361
# Task ID00065 of workflow 92 completed on fog_0 at time 15.328865000000016
# Task ID00043 of workflow 7 completed on iot_5 at time 15.331210000000016
# Task ID00047 of workflow 32 completed on iot_6 at time 15.331602500000027
# Task ID00055 of workflow 36 completed on server_0 at time 15.331816666666686
# Task ID00037 of workflow 74 completed on iot_5 at time 15.333510000000016
# Task ID00048 of workflow 32 completed on iot_3 at time 15.333542500000027
# Task ID00064 of workflow 3 completed on server_2 at time 15.338300833333362
# Task ID00066 of workflow 46 completed on fog_5 at time 15.339276666666686
# Task ID00067 of workflow 46 completed on fog_4 at time 15.339514166666687
# Task ID00056 of workflow 36 completed on fog_5 at time 15.339589166666686
# Task ID00065 of workflow 3 completed on iot_6 at time 15.341140833333363
# Task ID00068 of workflow 46 completed on server_0 at time 15.34380250000002
# Task ID00069 of workflow 46 completed on fog_7 at time 15.34405250000002
# Task ID00049 of workflow 32 completed on fog_5 at time 15.349124166666686
# Task ID00055 of workflow 80 completed on iot_2 at time 15.351520000000026
# Task ID00063 of workflow 29 completed on iot_2 at time 15.354160000000025
# Task ID00044 of workflow 7 completed on server_3 at time 15.364381666666683
# Task ID00038 of workflow 74 completed on server_3 at time 15.37092333333335
# Task ID00039 of workflow 74 completed on server_2 at time 15.371031666666683
# Task ID00079 of workflow 27 completed on iot_1 at time 15.37523583333337
# Task ID00043 of workflow 96 completed on iot_1 at time 15.377935833333371
# Task ID00048 of workflow 8 completed on iot_1 at time 15.37987583333337
# Task ID00057 of workflow 36 completed on fog_1 at time 15.382566666666685
# Task ID00058 of workflow 36 completed on fog_0 at time 15.388139166666685
# Task ID00051 of workflow 90 completed on iot_0 at time 15.389120000000025
# Task ID00052 of workflow 90 completed on fog_4 at time 15.389445000000025
# Task ID00041 of workflow 17 completed on iot_0 at time 15.391180000000025
# Task ID00060 of workflow 26 completed on iot_7 at time 15.39830500000002
# Task ID00061 of workflow 26 completed on server_3 at time 15.39853000000002
# Task ID00056 of workflow 83 completed on iot_7 at time 15.40080500000002
# Task ID00057 of workflow 97 completed on iot_4 at time 15.401608333333357
# Task ID00048 of workflow 81 completed on iot_4 at time 15.403548333333356
# Task ID00041 of workflow 93 completed on iot_4 at time 15.405608333333356
# Task ID00036 of workflow 4 completed on iot_8 at time 15.406215833333361
# Task ID00037 of workflow 4 completed on fog_2 at time 15.406503333333362
# Task ID00062 of workflow 26 completed on server_1 at time 15.40685500000002
# Task ID00063 of workflow 26 completed on fog_5 at time 15.40718500000002
# Task ID00044 of workflow 96 completed on server_4 at time 15.411107500000037
# Task ID00045 of workflow 96 completed on server_0 at time 15.41529583333337
# Task ID00046 of workflow 96 completed on fog_2 at time 15.415460833333372
# Task ID00049 of workflow 8 completed on server_4 at time 15.417464166666704
# Task ID00050 of workflow 8 completed on fog_4 at time 15.417649166666704
# Task ID00051 of workflow 8 completed on server_2 at time 15.427707500000038
# Task ID00066 of workflow 3 completed on iot_3 at time 15.445780833333362
# Task ID00045 of workflow 41 completed on iot_4 at time 15.455868333333356
# Task ID00042 of workflow 78 completed on iot_0 at time 15.461120000000026
# Task ID00046 of workflow 28 completed on iot_0 at time 15.462440000000026
# Task ID00039 of workflow 94 completed on iot_0 at time 15.463740000000026
# Task ID00040 of workflow 94 completed on fog_7 at time 15.469297500000026
# Task ID00041 of workflow 94 completed on fog_7 at time 15.469555000000026
# Task ID00051 of workflow 45 completed on iot_2 at time 15.474860000000024
# Task ID00052 of workflow 45 completed on server_3 at time 15.475076666666691
# Task ID00042 of workflow 94 completed on fog_6 at time 15.478297500000027
# Task ID00038 of workflow 4 completed on iot_6 at time 15.485003333333362
# Task ID00039 of workflow 4 completed on fog_2 at time 15.485165833333362
# Task ID00040 of workflow 74 completed on iot_3 at time 15.490240833333363
# Task ID00040 of workflow 4 completed on fog_5 at time 15.490723333333362
# Task ID00041 of workflow 4 completed on fog_0 at time 15.490980833333362
# Task ID00077 of workflow 52 completed on iot_8 at time 15.50979583333336
# Task ID00078 of workflow 52 completed on fog_5 at time 15.51009083333336
# Task ID00057 of workflow 65 completed on iot_9 at time 15.510897500000013
# Task ID00058 of workflow 65 completed on fog_1 at time 15.516470000000012
# Task ID00059 of workflow 65 completed on iot_6 at time 15.518390000000013
# Task ID00079 of workflow 52 completed on server_3 at time 15.51882583333336
# Task ID00080 of workflow 52 completed on server_4 at time 15.518992500000026
# Task ID00058 of workflow 51 completed on iot_2 at time 15.519440000000024
# Task ID00059 of workflow 51 completed on fog_3 at time 15.519680000000024
# Task ID00060 of workflow 65 completed on server_1 at time 15.525060000000012
# Task ID00061 of workflow 65 completed on fog_6 at time 15.525397500000013
# Task ID00081 of workflow 52 completed on fog_7 at time 15.527495000000027
# Task ID00082 of workflow 52 completed on server_2 at time 15.527696666666694
# Task ID00049 of workflow 11 completed on iot_4 at time 15.532148333333357
# Task ID00050 of workflow 11 completed on fog_7 at time 15.532333333333357
# Task ID00052 of workflow 85 completed on iot_4 at time 15.534748333333356
# Task ID00058 of workflow 97 completed on iot_3 at time 15.534820833333363
# Task ID00059 of workflow 97 completed on fog_2 at time 15.535060833333363
# Task ID00083 of workflow 52 completed on server_2 at time 15.537396666666695
# Task ID00043 of workflow 24 completed on iot_4 at time 15.537448333333357
# Task ID00061 of workflow 1 completed on iot_4 at time 15.540148333333358
# Task ID00053 of workflow 85 completed on fog_5 at time 15.544933333333356
# Task ID00051 of workflow 11 completed on fog_3 at time 15.547420833333357
# Task ID00052 of workflow 11 completed on fog_6 at time 15.547745833333357
# Task ID00062 of workflow 1 completed on fog_4 at time 15.552635833333358
# Task ID00054 of workflow 85 completed on fog_4 at time 15.552928333333359
# Task ID00047 of workflow 28 completed on iot_3 at time 15.588060833333364
# Task ID00048 of workflow 28 completed on fog_2 at time 15.588303333333364
# Task ID00055 of workflow 56 completed on iot_2 at time 15.589720000000025
# Task ID00050 of workflow 32 completed on iot_2 at time 15.591200000000025
# Task ID00056 of workflow 56 completed on iot_3 at time 15.592220000000024
# Task ID00060 of workflow 51 completed on iot_6 at time 15.599720000000024
# Task ID00051 of workflow 32 completed on server_1 at time 15.601258333333359
# Task ID00052 of workflow 32 completed on fog_4 at time 15.601583333333359
# Task ID00064 of workflow 72 completed on iot_9 at time 15.627357500000013
# Task ID00059 of workflow 31 completed on iot_9 at time 15.629277500000013
# Task ID00054 of workflow 40 completed on iot_9 at time 15.631617500000013
# Task ID00069 of workflow 62 completed on iot_9 at time 15.633617500000014
# Task ID00057 of workflow 56 completed on fog_7 at time 15.635197500000023
# Task ID00058 of workflow 56 completed on server_3 at time 15.638912500000023
# Task ID00059 of workflow 56 completed on server_3 at time 15.639072500000022
# Task ID00055 of workflow 40 completed on fog_3 at time 15.640402500000013
# Task ID00066 of workflow 66 completed on iot_4 at time 15.644788333333357
# Task ID00067 of workflow 0 completed on iot_4 at time 15.646688333333357
# Task ID00060 of workflow 56 completed on fog_5 at time 15.649077500000022
# Task ID00061 of workflow 56 completed on server_4 at time 15.649302500000022
# Task ID00042 of workflow 17 completed on iot_2 at time 15.661140000000026
# Task ID00043 of workflow 17 completed on fog_2 at time 15.661477500000027
# Task ID00055 of workflow 85 completed on iot_6 at time 15.670000000000025
# Task ID00057 of workflow 21 completed on iot_5 at time 15.677330000000016
# Task ID00041 of workflow 15 completed on iot_5 at time 15.679390000000016
# Task ID00058 of workflow 21 completed on fog_5 at time 15.682902500000015
# Task ID00059 of workflow 21 completed on fog_4 at time 15.683142500000015
# Task ID00044 of workflow 17 completed on server_0 at time 15.694649166666693
# Task ID00045 of workflow 17 completed on fog_2 at time 15.700931666666692
# Task ID00060 of workflow 31 completed on iot_3 at time 15.709317500000013
# Task ID00056 of workflow 85 completed on iot_3 at time 15.711817500000013
# Task ID00055 of workflow 37 completed on iot_5 at time 15.749670000000016
# Task ID00056 of workflow 37 completed on fog_7 at time 15.749982500000016
# Task ID00067 of workflow 9 completed on iot_5 at time 15.751570000000015
# Task ID00065 of workflow 55 completed on iot_5 at time 15.754410000000016
# Task ID00057 of workflow 85 completed on fog_3 at time 15.754795000000012
# Task ID00059 of workflow 76 completed on iot_5 at time 15.756330000000016
# Task ID00061 of workflow 35 completed on iot_5 at time 15.759030000000017
# Task ID00058 of workflow 85 completed on fog_2 at time 15.760367500000012
# Task ID00062 of workflow 35 completed on server_0 at time 15.767355000000016
# Task ID00051 of workflow 30 completed on iot_4 at time 15.767388333333356
# Task ID00043 of workflow 71 completed on iot_4 at time 15.770088333333357
# Task ID00063 of workflow 39 completed on iot_4 at time 15.772728333333356
# Task ID00041 of workflow 95 completed on iot_4 at time 15.774788333333357
# Task ID00037 of workflow 19 completed on iot_4 at time 15.777088333333356
# Task ID00064 of workflow 39 completed on fog_4 at time 15.787285833333357
# Task ID00070 of workflow 98 completed on iot_1 at time 15.78743583333337
# Task ID00065 of workflow 39 completed on fog_3 at time 15.787640833333358
# Task ID00060 of workflow 21 completed on iot_3 at time 15.791857500000013
# Task ID00046 of workflow 17 completed on iot_3 at time 15.793177500000013
# Task ID00071 of workflow 98 completed on fog_0 at time 15.79480083333337
# Task ID00052 of workflow 30 completed on iot_3 at time 15.795777500000012
# Task ID00044 of workflow 69 completed on iot_7 at time 15.798865000000019
# Task ID00066 of workflow 39 completed on fog_4 at time 15.800720833333358
# Task ID00067 of workflow 39 completed on fog_0 at time 15.800958333333359
# Task ID00053 of workflow 30 completed on server_3 at time 15.802567500000013
# Task ID00045 of workflow 69 completed on fog_3 at time 15.805147500000018
# Task ID00068 of workflow 39 completed on server_4 at time 15.805246666666692
# Task ID00046 of workflow 69 completed on server_1 at time 15.805257500000018
# Task ID00069 of workflow 39 completed on fog_1 at time 15.805496666666691
# Task ID00047 of workflow 69 completed on fog_4 at time 15.811912500000018
# Task ID00048 of workflow 69 completed on fog_0 at time 15.812155000000018
# Task ID00049 of workflow 5 completed on iot_5 at time 15.835310000000018
# Task ID00056 of workflow 80 completed on iot_5 at time 15.837810000000017
# Task ID00068 of workflow 67 completed on iot_1 at time 15.838895833333371
# Task ID00084 of workflow 22 completed on iot_1 at time 15.840575833333371
# Task ID00037 of workflow 14 completed on iot_1 at time 15.842875833333371
# Task ID00041 of workflow 60 completed on iot_1 at time 15.844935833333372
# Task ID00059 of workflow 77 completed on iot_1 at time 15.846855833333372
# Task ID00042 of workflow 60 completed on fog_1 at time 15.853678333333372
# Task ID00070 of workflow 39 completed on fog_6 at time 15.856441666666692
# Task ID00071 of workflow 39 completed on server_2 at time 15.861351666666692
# Task ID00072 of workflow 39 completed on fog_5 at time 15.861681666666692
# Task ID00070 of workflow 23 completed on iot_0 at time 15.871300000000026
# Task ID00073 of workflow 39 completed on fog_0 at time 15.873179166666693
# Task ID00049 of workflow 99 completed on iot_7 at time 15.87514500000002
# Task ID00041 of workflow 12 completed on iot_7 at time 15.87720500000002
# Task ID00042 of workflow 93 completed on iot_5 at time 15.907750000000018
# Task ID00044 of workflow 18 completed on iot_8 at time 15.90785583333336
# Task ID00043 of workflow 93 completed on fog_6 at time 15.908087500000018
# Task ID00052 of workflow 8 completed on iot_5 at time 15.910350000000017
# Task ID00067 of workflow 3 completed on iot_5 at time 15.912250000000016
# Task ID00041 of workflow 74 completed on iot_5 at time 15.914310000000016
# Task ID00068 of workflow 3 completed on server_2 at time 15.91653833333335
# Task ID00069 of workflow 3 completed on server_1 at time 15.916705000000016
# Task ID00042 of workflow 74 completed on fog_1 at time 15.923052500000017
# Task ID00071 of workflow 88 completed on iot_0 at time 15.930220000000027
# Task ID00043 of workflow 59 completed on iot_0 at time 15.932920000000028
# Task ID00067 of workflow 58 completed on iot_0 at time 15.934820000000027
# Task ID00059 of workflow 36 completed on iot_0 at time 15.936740000000027
# Task ID00044 of workflow 93 completed on server_3 at time 15.941259166666685
# Task ID00045 of workflow 93 completed on server_4 at time 15.945447500000018
# Task ID00060 of workflow 36 completed on fog_4 at time 15.946745000000027
# Task ID00061 of workflow 36 completed on server_2 at time 15.946970000000027
# Task ID00049 of workflow 75 completed on iot_7 at time 15.95348500000002
# Task ID00054 of workflow 33 completed on iot_7 at time 15.95582500000002
# Task ID00045 of workflow 18 completed on iot_3 at time 15.958115833333359
# Task ID00068 of workflow 0 completed on iot_5 at time 15.965770000000017
# Task ID00051 of workflow 10 completed on iot_1 at time 15.967555833333371
# Task ID00052 of workflow 10 completed on server_4 at time 15.967772500000038
# Task ID00050 of workflow 20 completed on iot_1 at time 15.969035833333372
# Task ID00070 of workflow 3 completed on fog_1 at time 15.973997500000017
# Task ID00053 of workflow 10 completed on fog_2 at time 15.977957500000038
# Task ID00054 of workflow 10 completed on fog_3 at time 15.978250000000038
# Task ID00057 of workflow 83 completed on iot_2 at time 16.004960000000025
# Task ID00058 of workflow 83 completed on fog_4 at time 16.010532500000025
# Task ID00060 of workflow 97 completed on iot_0 at time 16.016780000000026
# Task ID00061 of workflow 97 completed on server_0 at time 16.017005000000026
# Task ID00068 of workflow 9 completed on iot_5 at time 16.017230000000016
# Task ID00069 of workflow 9 completed on server_0 at time 16.01739666666668
# Task ID00062 of workflow 97 completed on server_4 at time 16.025330000000025
# Task ID00063 of workflow 97 completed on fog_3 at time 16.025660000000027
# Task ID00044 of workflow 13 completed on iot_9 at time 16.031677500000015
# Task ID00043 of workflow 47 completed on iot_9 at time 16.034377500000016
# Task ID00064 of workflow 97 completed on server_4 at time 16.035365000000027
# Task ID00050 of workflow 42 completed on iot_9 at time 16.035857500000017
# Task ID00060 of workflow 57 completed on iot_7 at time 16.03586500000002
# Task ID00061 of workflow 57 completed on server_3 at time 16.03609000000002
# Task ID00045 of workflow 13 completed on fog_1 at time 16.037960000000016
# Task ID00065 of workflow 97 completed on fog_1 at time 16.038315000000015
# Task ID00052 of workflow 73 completed on iot_7 at time 16.03846500000002
# Task ID00053 of workflow 8 completed on iot_3 at time 16.039595833333358
# Task ID00054 of workflow 8 completed on fog_2 at time 16.03988833333336
# Task ID00053 of workflow 73 completed on server_4 at time 16.04525500000002
# Task ID00062 of workflow 57 completed on fog_7 at time 16.048577500000018
# Task ID00055 of workflow 8 completed on fog_4 at time 16.048673333333358
# Task ID00044 of workflow 47 completed on server_0 at time 16.067549166666684
# Task ID00056 of workflow 8 completed on server_0 at time 16.067757500000017
# Task ID00066 of workflow 92 completed on iot_1 at time 16.073675833333372
# Task ID00070 of workflow 62 completed on iot_6 at time 16.077560000000023
# Task ID00059 of workflow 85 completed on iot_6 at time 16.07948000000002
# Task ID00061 of workflow 21 completed on iot_6 at time 16.082180000000022
# Task ID00053 of workflow 45 completed on iot_2 at time 16.086440000000024
# Task ID00060 of workflow 85 completed on fog_3 at time 16.08948500000002
# Task ID00062 of workflow 21 completed on fog_7 at time 16.09466750000002
# Task ID00063 of workflow 21 completed on fog_5 at time 16.094997500000023
# Task ID00057 of workflow 8 completed on server_1 at time 16.09640916666668
# Task ID00067 of workflow 92 completed on server_1 at time 16.096567500000017
# Task ID00053 of workflow 11 completed on iot_0 at time 16.098260000000025
# Task ID00071 of workflow 3 completed on iot_3 at time 16.09851583333336
# Task ID00058 of workflow 8 completed on server_4 at time 16.10012416666668
# Task ID00072 of workflow 3 completed on server_4 at time 16.10034416666668
# Task ID00068 of workflow 92 completed on server_0 at time 16.100855833333352
# Task ID00059 of workflow 8 completed on server_0 at time 16.101015833333353
# Task ID00042 of workflow 84 completed on iot_9 at time 16.105797500000016
# Task ID00043 of workflow 84 completed on fog_7 at time 16.106135000000016
# Task ID00046 of workflow 50 completed on iot_9 at time 16.107117500000015
# Task ID00064 of workflow 21 completed on fog_3 at time 16.10955500000002
# Task ID00065 of workflow 21 completed on fog_3 at time 16.10991000000002
# Task ID00060 of workflow 8 completed on fog_6 at time 16.111020833333352
# Task ID00073 of workflow 3 completed on fog_4 at time 16.11184166666668
# Task ID00074 of workflow 3 completed on server_0 at time 16.112023333333347
# Task ID00066 of workflow 21 completed on server_2 at time 16.11863000000002
# Task ID00053 of workflow 90 completed on iot_7 at time 16.11994500000002
# Task ID00054 of workflow 90 completed on server_1 at time 16.12014000000002
# Task ID00085 of workflow 64 completed on iot_4 at time 16.120148333333358
# Task ID00055 of workflow 90 completed on fog_6 at time 16.12892500000002
# Task ID00056 of workflow 90 completed on server_2 at time 16.129133333333353
# Task ID00049 of workflow 81 completed on iot_1 at time 16.149955833333372
# Task ID00057 of workflow 90 completed on server_1 at time 16.15778500000002
# Task ID00050 of workflow 81 completed on server_1 at time 16.157908333333353
# Task ID00049 of workflow 28 completed on iot_2 at time 16.162720000000025
# Task ID00061 of workflow 51 completed on iot_2 at time 16.165420000000026
# Task ID00067 of workflow 66 completed on iot_2 at time 16.167320000000025
# Task ID00051 of workflow 81 completed on server_4 at time 16.167966666666686
# Task ID00068 of workflow 66 completed on server_0 at time 16.17160833333336
# Task ID00062 of workflow 51 completed on fog_5 at time 16.177907500000025
# Task ID00053 of workflow 32 completed on iot_0 at time 16.179740000000024
# Task ID00054 of workflow 32 completed on fog_6 at time 16.180032500000024
# Task ID00056 of workflow 40 completed on iot_0 at time 16.182240000000025
# Task ID00061 of workflow 31 completed on iot_0 at time 16.184940000000026
# Task ID00055 of workflow 32 completed on server_0 at time 16.18588916666669
# Task ID00056 of workflow 32 completed on fog_2 at time 16.18620166666669
# Task ID00062 of workflow 31 completed on server_4 at time 16.193265000000025
# Task ID00063 of workflow 31 completed on fog_6 at time 16.193595000000027
# Task ID00049 of workflow 2 completed on iot_4 at time 16.19642833333336
# Task ID00050 of workflow 2 completed on fog_1 at time 16.196613333333357
# Task ID00051 of workflow 20 completed on iot_6 at time 16.20288000000002
# Task ID00064 of workflow 31 completed on server_4 at time 16.203300000000027
# Task ID00051 of workflow 2 completed on fog_7 at time 16.211700833333357
# Task ID00062 of workflow 65 completed on iot_7 at time 16.21984500000002
# Task ID00063 of workflow 65 completed on server_0 at time 16.22006500000002
# Task ID00057 of workflow 40 completed on fog_4 at time 16.225217500000024
# Task ID00051 of workflow 82 completed on iot_9 at time 16.227817500000015
# Task ID00052 of workflow 82 completed on fog_6 at time 16.228142500000015
# Task ID00064 of workflow 65 completed on fog_0 at time 16.234622500000018
# Task ID00065 of workflow 65 completed on fog_0 at time 16.234977500000017
# Task ID00042 of workflow 15 completed on iot_2 at time 16.237260000000024
# Task ID00043 of workflow 15 completed on fog_3 at time 16.237597500000025
# Task ID00046 of workflow 93 completed on iot_2 at time 16.238580000000024
# Task ID00050 of workflow 75 completed on iot_2 at time 16.240060000000025
# Task ID00047 of workflow 93 completed on fog_1 at time 16.245235000000022
# Task ID00057 of workflow 49 completed on iot_8 at time 16.25167583333336
# Task ID00056 of workflow 63 completed on iot_8 at time 16.25417583333336
# Task ID00065 of workflow 70 completed on iot_8 at time 16.25701583333336
# Task ID00067 of workflow 79 completed on iot_8 at time 16.258915833333358
# Task ID00060 of workflow 76 completed on iot_0 at time 16.264980000000026
# Task ID00042 of workflow 25 completed on iot_4 at time 16.266368333333357
# Task ID00064 of workflow 26 completed on iot_1 at time 16.266415833333372
# Task ID00072 of workflow 98 completed on iot_0 at time 16.267620000000026
# Task ID00057 of workflow 32 completed on fog_4 at time 16.268195000000023
# Task ID00067 of workflow 68 completed on iot_4 at time 16.268268333333356
# Task ID00043 of workflow 25 completed on iot_3 at time 16.269068333333358
# Task ID00054 of workflow 30 completed on iot_0 at time 16.269960000000026
# Task ID00066 of workflow 70 completed on fog_1 at time 16.270095833333357
# Task ID00055 of workflow 10 completed on iot_6 at time 16.273160000000022
# Task ID00054 of workflow 45 completed on iot_6 at time 16.275500000000022
# Task ID00056 of workflow 10 completed on iot_3 at time 16.275660000000023
# Task ID00058 of workflow 32 completed on fog_1 at time 16.275668333333357
# Task ID00067 of workflow 21 completed on iot_6 at time 16.27740000000002
# Task ID00045 of workflow 89 completed on iot_9 at time 16.278077500000016
# Task ID00046 of workflow 89 completed on server_3 at time 16.278187500000016
# Task ID00053 of workflow 82 completed on fog_4 at time 16.278380000000023
# Task ID00063 of workflow 51 completed on iot_6 at time 16.28004000000002
# Task ID00061 of workflow 16 completed on iot_9 at time 16.280777500000017
# Task ID00055 of workflow 45 completed on fog_6 at time 16.284285000000022
# Task ID00055 of workflow 30 completed on fog_1 at time 16.284453333333357
# Task ID00054 of workflow 82 completed on fog_1 at time 16.284745833333357
# Task ID00044 of workflow 15 completed on fog_5 at time 16.287355000000023
# Task ID00048 of workflow 93 completed on fog_5 at time 16.28759750000002
# Task ID00065 of workflow 26 completed on fog_5 at time 16.28795250000002
# Task ID00062 of workflow 16 completed on server_2 at time 16.289102500000016
# Task ID00068 of workflow 21 completed on fog_6 at time 16.29071750000002
# Task ID00049 of workflow 93 completed on server_3 at time 16.293954166666687
# Task ID00050 of workflow 93 completed on fog_4 at time 16.294139166666685
# Task ID00066 of workflow 26 completed on server_2 at time 16.297822500000017
# Task ID00067 of workflow 26 completed on fog_7 at time 16.298060000000017
# Task ID00058 of workflow 6 completed on iot_8 at time 16.303495833333358
# Task ID00059 of workflow 6 completed on server_3 at time 16.30365583333336
# Task ID00057 of workflow 10 completed on server_0 at time 16.30431166666669
# Task ID00059 of workflow 32 completed on server_0 at time 16.30447166666669
# Task ID00068 of workflow 26 completed on fog_3 at time 16.304492500000016
# Task ID00056 of workflow 30 completed on server_0 at time 16.304680000000022
# Task ID00061 of workflow 48 completed on iot_8 at time 16.30619583333336
# Task ID00051 of workflow 93 completed on fog_1 at time 16.309226666666685
# Task ID00052 of workflow 93 completed on fog_0 at time 16.309551666666685
# Task ID00055 of workflow 33 completed on iot_2 at time 16.310340000000025
# Task ID00056 of workflow 33 completed on fog_0 at time 16.310652500000025
# Task ID00069 of workflow 0 completed on iot_2 at time 16.312340000000024
# Task ID00046 of workflow 13 completed on iot_2 at time 16.313660000000024
# Task ID00053 of workflow 93 completed on server_3 at time 16.316341666666684
# Task ID00054 of workflow 93 completed on server_0 at time 16.316536666666686
# Task ID00060 of workflow 32 completed on fog_1 at time 16.319231666666685
# Task ID00047 of workflow 96 completed on iot_1 at time 16.31965583333337
# Task ID00043 of workflow 94 completed on iot_1 at time 16.322355833333372
# Task ID00055 of workflow 93 completed on server_3 at time 16.322393333333352
# Task ID00056 of workflow 93 completed on server_2 at time 16.322601666666685
# Task ID00045 of workflow 15 completed on iot_3 at time 16.337615000000024
# Task ID00046 of workflow 15 completed on fog_2 at time 16.337780000000024
# Task ID00055 of workflow 61 completed on iot_4 at time 16.338548333333357
# Task ID00047 of workflow 15 completed on fog_7 at time 16.344435000000022
# Task ID00049 of workflow 69 completed on iot_0 at time 16.346240000000027
# Task ID00074 of workflow 39 completed on iot_0 at time 16.348420000000026
# Task ID00050 of workflow 99 completed on iot_0 at time 16.349900000000027
# Task ID00058 of workflow 87 completed on iot_8 at time 16.35077583333336
# Task ID00059 of workflow 87 completed on fog_1 at time 16.35101583333336
# Task ID00057 of workflow 93 completed on server_3 at time 16.35125333333335
# Task ID00043 of workflow 74 completed on iot_0 at time 16.352600000000027
# Task ID00080 of workflow 27 completed on iot_8 at time 16.352775833333357
# Task ID00084 of workflow 52 completed on iot_8 at time 16.354455833333358
# Task ID00072 of workflow 88 completed on iot_0 at time 16.355240000000027
# Task ID00075 of workflow 39 completed on server_1 at time 16.355511666666693
# Task ID00081 of workflow 27 completed on server_2 at time 16.35844416666669
# Task ID00060 of workflow 87 completed on fog_1 at time 16.36102083333336
# Task ID00057 of workflow 80 completed on iot_5 at time 16.361050000000017
# Task ID00061 of workflow 87 completed on iot_3 at time 16.36372083333336
# Task ID00051 of workflow 99 completed on fog_2 at time 16.364987500000026
# Task ID00052 of workflow 99 completed on server_0 at time 16.365204166666693
# Task ID00058 of workflow 80 completed on fog_6 at time 16.366622500000016
# Task ID00053 of workflow 99 completed on fog_4 at time 16.375389166666693
# Task ID00054 of workflow 99 completed on server_0 at time 16.375584166666695
# Task ID00073 of workflow 88 completed on fog_2 at time 16.376485000000027
# Task ID00055 of workflow 99 completed on server_1 at time 16.38144083333336
# Task ID00085 of workflow 52 completed on server_4 at time 16.38304416666669
# Task ID00066 of workflow 91 completed on iot_9 at time 16.385417500000017
# Task ID00068 of workflow 58 completed on iot_0 at time 16.406700000000026
# Task ID00071 of workflow 62 completed on iot_5 at time 16.419970000000017
# Task ID00062 of workflow 56 completed on iot_1 at time 16.422255833333374
# Task ID00086 of workflow 64 completed on iot_2 at time 16.432660000000023
# Task ID00087 of workflow 64 completed on server_3 at time 16.432883333333358
# Task ID00064 of workflow 29 completed on iot_4 at time 16.455008333333357
# Task ID00046 of workflow 41 completed on iot_4 at time 16.456328333333357
# Task ID00043 of workflow 78 completed on iot_4 at time 16.459028333333357
# Task ID00066 of workflow 55 completed on iot_8 at time 16.459095833333357
# Task ID00063 of workflow 1 completed on iot_4 at time 16.461668333333357
# Task ID00047 of workflow 41 completed on fog_7 at time 16.462983333333355
# Task ID00067 of workflow 55 completed on fog_7 at time 16.463220833333356
# Task ID00048 of workflow 41 completed on fog_7 at time 16.463463333333355
# Task ID00053 of workflow 44 completed on iot_9 at time 16.466897500000016
# Task ID00046 of workflow 86 completed on iot_9 at time 16.468217500000016
# Task ID00068 of workflow 55 completed on fog_5 at time 16.469653333333355
# Task ID00049 of workflow 41 completed on server_2 at time 16.46982000000002
# Task ID00069 of workflow 55 completed on fog_4 at time 16.469903333333356
# Task ID00047 of workflow 50 completed on iot_5 at time 16.473210000000016
# Task ID00047 of workflow 86 completed on fog_1 at time 16.474872500000014
# Task ID00052 of workflow 20 completed on iot_5 at time 16.475810000000017
# Task ID00064 of workflow 1 completed on fog_3 at time 16.476225833333356
# Task ID00065 of workflow 1 completed on server_3 at time 16.47646250000002
# Task ID00056 of workflow 45 completed on iot_5 at time 16.478310000000018
# Task ID00053 of workflow 20 completed on fog_1 at time 16.485995000000017
# Task ID00066 of workflow 1 completed on fog_2 at time 16.48954250000002
# Task ID00067 of workflow 1 completed on fog_4 at time 16.48978000000002
# Task ID00042 of workflow 95 completed on iot_1 at time 16.492195833333373
# Task ID00043 of workflow 95 completed on fog_6 at time 16.492533333333373
# Task ID00068 of workflow 1 completed on server_4 at time 16.494068333333356
# Task ID00069 of workflow 1 completed on fog_2 at time 16.494318333333357
# Task ID00057 of workflow 45 completed on fog_0 at time 16.521287500000017
# Task ID00058 of workflow 10 completed on iot_5 at time 16.522890000000018
# Task ID00058 of workflow 45 completed on server_3 at time 16.525002500000017
# Task ID00059 of workflow 45 completed on iot_5 at time 16.526922500000016
# Task ID00051 of workflow 42 completed on iot_0 at time 16.527400000000025
# Task ID00052 of workflow 42 completed on fog_5 at time 16.527725000000025
# Task ID00054 of workflow 73 completed on iot_0 at time 16.529740000000025
# Task ID00063 of workflow 57 completed on iot_0 at time 16.532380000000025
# Task ID00060 of workflow 45 completed on server_4 at time 16.533592500000015
# Task ID00069 of workflow 92 completed on iot_0 at time 16.534380000000024
# Task ID00055 of workflow 73 completed on server_2 at time 16.53559666666669
# Task ID00061 of workflow 45 completed on iot_5 at time 16.536292500000016
# Task ID00038 of workflow 19 completed on iot_4 at time 16.540168333333355
# Task ID00064 of workflow 57 completed on server_1 at time 16.542085000000025
# Task ID00039 of workflow 19 completed on server_1 at time 16.54219333333336
# Task ID00065 of workflow 57 completed on fog_6 at time 16.542440000000024
# Task ID00047 of workflow 17 completed on iot_1 at time 16.54543583333337
# Task ID00048 of workflow 17 completed on server_4 at time 16.54559750000004
# Task ID00050 of workflow 5 completed on iot_1 at time 16.546915833333372
# Task ID00062 of workflow 45 completed on fog_2 at time 16.548780000000015
# Task ID00066 of workflow 57 completed on fog_3 at time 16.555520000000023
# Task ID00067 of workflow 57 completed on server_4 at time 16.555678333333358
# Task ID00057 of workflow 37 completed on iot_7 at time 16.56366500000002
# Task ID00069 of workflow 67 completed on iot_7 at time 16.56566500000002
# Task ID00062 of workflow 54 completed on iot_9 at time 16.568117500000017
# Task ID00063 of workflow 54 completed on server_2 at time 16.568337500000016
# Task ID00048 of workflow 43 completed on iot_9 at time 16.57005750000002
# Task ID00054 of workflow 34 completed on iot_9 at time 16.57239750000002
# Task ID00049 of workflow 43 completed on fog_6 at time 16.579592500000018
# Task ID00064 of workflow 54 completed on fog_5 at time 16.582895000000015
# Task ID00065 of workflow 54 completed on fog_0 at time 16.583250000000014
# Task ID00070 of workflow 67 completed on server_3 at time 16.599628333333353
# Task ID00050 of workflow 43 completed on server_3 at time 16.599751666666688
# Task ID00066 of workflow 54 completed on server_3 at time 16.608471666666688
# Task ID00051 of workflow 43 completed on fog_6 at time 16.614839166666687
# Task ID00052 of workflow 43 completed on fog_0 at time 16.615164166666688
# Task ID00057 of workflow 63 completed on iot_6 at time 16.623860000000022
# Task ID00060 of workflow 77 completed on iot_1 at time 16.626955833333373
# Task ID00058 of workflow 63 completed on fog_0 at time 16.62943250000002
# Task ID00059 of workflow 63 completed on iot_5 at time 16.63135250000002
# Task ID00066 of workflow 65 completed on iot_0 at time 16.639020000000023
# Task ID00067 of workflow 65 completed on server_1 at time 16.63917833333336
# Task ID00081 of workflow 38 completed on iot_9 at time 16.64041750000002
# Task ID00082 of workflow 38 completed on server_0 at time 16.640619166666685
# Task ID00060 of workflow 63 completed on fog_7 at time 16.64135750000002
# Task ID00043 of workflow 53 completed on iot_9 at time 16.64311750000002
# Task ID00038 of workflow 14 completed on iot_7 at time 16.64416500000002
# Task ID00039 of workflow 14 completed on fog_4 at time 16.644327500000017
# Task ID00043 of workflow 60 completed on iot_7 at time 16.64686500000002
# Task ID00083 of workflow 38 completed on server_4 at time 16.650319166666684
# Task ID00084 of workflow 38 completed on fog_4 at time 16.650529166666683
# Task ID00058 of workflow 49 completed on iot_0 at time 16.683600000000023
# Task ID00071 of workflow 23 completed on iot_1 at time 16.685875833333373
# Task ID00072 of workflow 23 completed on server_3 at time 16.686095833333372
# Task ID00063 of workflow 16 completed on iot_0 at time 16.686240000000023
# Task ID00040 of workflow 14 completed on iot_5 at time 16.688787500000018
# Task ID00041 of workflow 14 completed on fog_5 at time 16.689045000000018
# Task ID00059 of workflow 49 completed on iot_5 at time 16.690707500000016
# Task ID00085 of workflow 38 completed on fog_2 at time 16.693411666666684
# Task ID00060 of workflow 49 completed on server_0 at time 16.697377500000016
# Task ID00073 of workflow 23 completed on fog_1 at time 16.697593333333373
# Task ID00061 of workflow 49 completed on fog_6 at time 16.697715000000017
# Task ID00074 of workflow 23 completed on server_4 at time 16.69777500000004
# Task ID00042 of workflow 14 completed on fog_5 at time 16.697787500000018
# Task ID00075 of workflow 23 completed on fog_3 at time 16.70841250000004
# Task ID00076 of workflow 23 completed on server_2 at time 16.708550833333373
# Task ID00077 of workflow 23 completed on fog_7 at time 16.721498333333372
# Task ID00078 of workflow 23 completed on server_4 at time 16.72169500000004
# Task ID00073 of workflow 98 completed on iot_7 at time 16.73884500000002
# Task ID00074 of workflow 98 completed on fog_3 at time 16.73911750000002
# Task ID00068 of workflow 68 completed on iot_7 at time 16.790305000000018
# Task ID00069 of workflow 68 completed on fog_5 at time 16.79055500000002
# Task ID00062 of workflow 49 completed on iot_5 at time 16.797615000000018
# Task ID00085 of workflow 22 completed on iot_8 at time 16.80215583333336
# Task ID00086 of workflow 22 completed on fog_1 at time 16.81703083333336
# Task ID00087 of workflow 22 completed on server_2 at time 16.817254166666693
# Task ID00088 of workflow 22 completed on server_0 at time 16.827887500000028
# Task ID00089 of workflow 22 completed on iot_5 at time 16.83020750000003
# Task ID00044 of workflow 25 completed on iot_2 at time 16.830720000000024
# Task ID00045 of workflow 25 completed on fog_2 at time 16.837002500000025
# Task ID00046 of workflow 25 completed on fog_4 at time 16.837167500000024
# Task ID00090 of workflow 22 completed on server_3 at time 16.84079750000003
# Task ID00091 of workflow 22 completed on fog_5 at time 16.84109000000003
# Task ID00070 of workflow 68 completed on fog_3 at time 16.841500000000018
# Task ID00047 of workflow 25 completed on server_4 at time 16.84160416666669
# Task ID00048 of workflow 25 completed on server_4 at time 16.84176583333336
# Task ID00047 of workflow 89 completed on iot_7 at time 16.843545000000017
# Task ID00048 of workflow 89 completed on iot_5 at time 16.845485000000018
# Task ID00071 of workflow 68 completed on fog_4 at time 16.848865000000018
# Task ID00072 of workflow 68 completed on fog_6 at time 16.84919500000002
# Task ID00049 of workflow 25 completed on fog_5 at time 16.851300833333358
# Task ID00042 of workflow 12 completed on iot_8 at time 16.872095833333358
# Task ID00043 of workflow 12 completed on fog_6 at time 16.87243333333336
# Task ID00055 of workflow 82 completed on iot_2 at time 16.901000000000025
# Task ID00070 of workflow 1 completed on iot_3 at time 16.901878333333357
# Task ID00059 of workflow 10 completed on iot_3 at time 16.903798333333356
# Task ID00044 of workflow 12 completed on server_3 at time 16.905605000000026
# Task ID00071 of workflow 1 completed on server_0 at time 16.906788333333356
# ...
# Task ID00087 of workflow 17 completed on iot_8 at time 31.328760833333394
# Task ID00001 of workflow 74 completed on iot_8 at time 31.330360833333394
# Workflow 74 is completed! Total completed workflows: 79
# Task ID00088 of workflow 60 completed on fog_5 at time 31.341620833333398
# Task ID00089 of workflow 60 completed on fog_2 at time 31.341910833333397
# Task ID00088 of workflow 17 completed on fog_1 at time 31.344710833333394
# Task ID00089 of workflow 17 completed on server_3 at time 31.344904166666726
# Task ID00090 of workflow 60 completed on fog_3 at time 31.357795833333398
# Task ID00091 of workflow 60 completed on fog_2 at time 31.3580883333334
# Task ID00090 of workflow 17 completed on fog_6 at time 31.360789166666727
# Task ID00091 of workflow 17 completed on server_4 at time 31.36098416666673
# Task ID00092 of workflow 95 completed on iot_2 at time 31.3789791666667
# Task ID00093 of workflow 95 completed on iot_9 at time 31.3803791666667
# Task ID00094 of workflow 95 completed on fog_1 at time 31.3924991666667
# Task ID00095 of workflow 95 completed on server_0 at time 31.392622500000034
# Task ID00090 of workflow 69 completed on iot_6 at time 31.3943591666667
# Task ID00096 of workflow 95 completed on fog_6 at time 31.406847500000033
# Task ID00091 of workflow 69 completed on fog_6 at time 31.407140000000034
# Task ID00097 of workflow 95 completed on iot_7 at time 31.408807500000034
# Task ID00092 of workflow 69 completed on fog_7 at time 31.421100000000035
# Task ID00093 of workflow 69 completed on server_3 at time 31.4212166666667
# Task ID00088 of workflow 14 completed on iot_3 at time 31.450590833333397
# Task ID00089 of workflow 14 completed on server_1 at time 31.45078416666673
# Task ID00090 of workflow 4 completed on iot_8 at time 31.457440833333393
# Task ID00091 of workflow 4 completed on fog_7 at time 31.457733333333394
# Task ID00095 of workflow 34 completed on iot_8 at time 31.458920833333394
# Task ID00099 of workflow 15 completed on iot_8 at time 31.460980833333394
# Task ID00000 of workflow 15 completed on server_0 at time 31.46103750000006
# Task ID00001 of workflow 82 completed on iot_8 at time 31.462580833333394
# Workflow 82 is completed! Total completed workflows: 80
# Task ID00090 of workflow 14 completed on fog_0 at time 31.46666916666673
# Task ID00091 of workflow 14 completed on iot_3 at time 31.46900916666673
# Task ID00092 of workflow 14 completed on fog_0 at time 31.48296916666673
# Task ID00093 of workflow 14 completed on fog_5 at time 31.48314416666673
# Task ID00088 of workflow 19 completed on iot_2 at time 31.5065791666667
# Task ID00089 of workflow 19 completed on fog_6 at time 31.5068691666667
# Task ID00094 of workflow 69 completed on iot_0 at time 31.5181766666667
# Task ID00095 of workflow 69 completed on fog_1 at time 31.5183616666667
# Task ID00001 of workflow 15 completed on iot_0 at time 31.5197766666667
# Workflow 15 is completed! Total completed workflows: 81
# Task ID00096 of workflow 69 completed on fog_2 at time 31.5325866666667
# Task ID00092 of workflow 4 completed on iot_7 at time 31.569413333333394
# Task ID00093 of workflow 4 completed on iot_5 at time 31.570813333333394
# Task ID00094 of workflow 14 completed on iot_1 at time 31.58010416666673
# Task ID00095 of workflow 14 completed on fog_2 at time 31.580289166666727
# Task ID00096 of workflow 14 completed on fog_6 at time 31.594514166666727
# Task ID00097 of workflow 14 completed on iot_3 at time 31.596474166666727
# Task ID00092 of workflow 17 completed on iot_2 at time 31.6182591666667
# Task ID00093 of workflow 17 completed on server_2 at time 31.618375833333367
# Task ID00090 of workflow 19 completed on iot_9 at time 31.6339491666667
# Task ID00091 of workflow 19 completed on iot_4 at time 31.6362891666667
# Task ID00096 of workflow 34 completed on iot_7 at time 31.683213333333395
# Task ID00094 of workflow 17 completed on iot_1 at time 31.715335833333366
# Task ID00095 of workflow 17 completed on server_3 at time 31.7154591666667
# Task ID00097 of workflow 34 completed on iot_1 at time 31.717295833333367
# Task ID00098 of workflow 95 completed on iot_2 at time 31.7177991666667
# Task ID00097 of workflow 69 completed on iot_2 at time 31.7197591666667
# Task ID00096 of workflow 17 completed on fog_5 at time 31.7296841666667
# Task ID00099 of workflow 95 completed on fog_5 at time 31.7299416666667
# Task ID00000 of workflow 95 completed on fog_6 at time 31.7300266666667
# Task ID00001 of workflow 95 completed on iot_1 at time 31.7316266666667
# Workflow 95 is completed! Total completed workflows: 82
# Task ID00097 of workflow 17 completed on iot_6 at time 31.7316441666667
# Task ID00098 of workflow 17 completed on fog_4 at time 31.7440866666667
# Task ID00092 of workflow 19 completed on iot_5 at time 31.7479691666667
# Task ID00093 of workflow 19 completed on server_0 at time 31.748085833333366
# Task ID00099 of workflow 17 completed on iot_5 at time 31.7500291666667
# Task ID00000 of workflow 17 completed on fog_7 at time 31.750114166666698
# Task ID00001 of workflow 17 completed on fog_1 at time 31.750314166666698
# Workflow 17 is completed! Total completed workflows: 83
# Task ID00085 of workflow 47 completed on iot_8 at time 31.805640833333396
# Task ID00098 of workflow 69 completed on iot_4 at time 31.819299166666703
# Task ID00099 of workflow 69 completed on fog_4 at time 31.819556666666703
# Task ID00000 of workflow 69 completed on fog_1 at time 31.8196416666667
# Task ID00086 of workflow 47 completed on fog_7 at time 31.820515833333396
# Task ID00087 of workflow 47 completed on iot_0 at time 31.823195833333397
# Task ID00094 of workflow 19 completed on iot_7 at time 31.845045833333366
# Task ID00095 of workflow 19 completed on iot_4 at time 31.846525833333367
# Task ID00001 of workflow 69 completed on iot_7 at time 31.846645833333366
# Workflow 69 is completed! Total completed workflows: 84
# Task ID00096 of workflow 19 completed on fog_6 at time 31.860750833333366
# Task ID00097 of workflow 19 completed on iot_1 at time 31.862710833333367
# Task ID00098 of workflow 83 completed on iot_8 at time 31.905180833333397
# Task ID00093 of workflow 94 completed on iot_8 at time 31.906580833333397
# Task ID00099 of workflow 83 completed on iot_3 at time 31.907240833333397
# Task ID00000 of workflow 83 completed on server_3 at time 31.907297500000062
# Task ID00001 of workflow 83 completed on iot_9 at time 31.908897500000062
# Workflow 83 is completed! Total completed workflows: 85
# Task ID00089 of workflow 40 completed on iot_8 at time 31.908900833333398
# Task ID00000 of workflow 49 completed on iot_8 at time 31.909580833333397
# Task ID00001 of workflow 49 completed on fog_4 at time 31.909780833333397
# Workflow 49 is completed! Total completed workflows: 86
# Task ID00094 of workflow 94 completed on fog_0 at time 31.918700833333396
# Task ID00095 of workflow 94 completed on fog_5 at time 31.918885833333395
# Task ID00090 of workflow 40 completed on fog_2 at time 31.9247858333334
# Task ID00091 of workflow 40 completed on iot_6 at time 31.9271258333334
# Task ID00092 of workflow 40 completed on fog_2 at time 31.9410858333334
# Task ID00098 of workflow 19 completed on iot_5 at time 31.962250833333368
# Task ID00099 of workflow 19 completed on server_0 at time 31.962422500000034
# Task ID00000 of workflow 19 completed on iot_3 at time 31.963102500000034
# Task ID00088 of workflow 47 completed on iot_7 at time 31.974245833333367
# Task ID00089 of workflow 47 completed on server_2 at time 31.9744391666667
# Task ID00090 of workflow 47 completed on server_2 at time 31.9850291666667
# Task ID00091 of workflow 47 completed on fog_5 at time 31.9853216666667
# Task ID00094 of workflow 45 completed on iot_8 at time 32.006540833333396
# Task ID00095 of workflow 45 completed on fog_1 at time 32.0067258333334
# Task ID00096 of workflow 45 completed on fog_2 at time 32.0209508333334
# Task ID00097 of workflow 45 completed on server_2 at time 32.021114166666734
# Task ID00098 of workflow 45 completed on fog_0 at time 32.03355666666673
# Task ID00099 of workflow 45 completed on server_3 at time 32.0337283333334
# Task ID00096 of workflow 94 completed on iot_7 at time 32.08804583333337
# Task ID00097 of workflow 94 completed on fog_1 at time 32.08829083333337
# Task ID00000 of workflow 45 completed on iot_7 at time 32.08872583333337
# Task ID00001 of workflow 45 completed on iot_2 at time 32.090325833333374
# Workflow 45 is completed! Total completed workflows: 87
# Task ID00092 of workflow 47 completed on iot_9 at time 32.0970016666667
# Task ID00098 of workflow 94 completed on fog_4 at time 32.100733333333366
# Task ID00093 of workflow 47 completed on fog_4 at time 32.100908333333365
# Task ID00099 of workflow 94 completed on fog_4 at time 32.10116583333336
# Task ID00094 of workflow 47 completed on server_0 at time 32.108988333333365
# Task ID00000 of workflow 94 completed on server_0 at time 32.10904500000003
# Task ID00095 of workflow 47 completed on fog_3 at time 32.109173333333366
# Task ID00001 of workflow 94 completed on iot_4 at time 32.110645000000034
# Workflow 94 is completed! Total completed workflows: 88
# Task ID00083 of workflow 50 completed on iot_8 at time 32.122940833333395
# Task ID00084 of workflow 50 completed on server_2 at time 32.1230808333334
# Task ID00093 of workflow 24 completed on iot_8 at time 32.12434083333339
# Task ID00001 of workflow 96 completed on iot_8 at time 32.125940833333395
# Workflow 96 is completed! Total completed workflows: 89
# Task ID00095 of workflow 93 completed on iot_8 at time 32.127420833333396
# Task ID00096 of workflow 93 completed on server_3 at time 32.13690416666673
# Task ID00097 of workflow 93 completed on fog_2 at time 32.13714916666673
# Task ID00085 of workflow 50 completed on fog_4 at time 32.165963333333394
# Task ID00086 of workflow 50 completed on fog_4 at time 32.1808383333334
# Task ID00087 of workflow 50 completed on fog_7 at time 32.1811733333334
# Task ID00094 of workflow 24 completed on iot_6 at time 32.221300833333395
# Task ID00095 of workflow 24 completed on fog_7 at time 32.221485833333396
# Task ID00096 of workflow 47 completed on iot_3 at time 32.222973333333364
# Task ID00094 of workflow 78 completed on iot_8 at time 32.2243808333334
# Task ID00095 of workflow 78 completed on fog_1 at time 32.2245658333334
# Task ID00097 of workflow 47 completed on iot_3 at time 32.22493333333336
# Task ID00098 of workflow 47 completed on fog_2 at time 32.23737583333336
# Task ID00099 of workflow 47 completed on iot_7 at time 32.23943583333336
# Task ID00088 of workflow 50 completed on iot_1 at time 32.3087733333334
# Task ID00089 of workflow 50 completed on iot_6 at time 32.311093333333396
# Task ID00090 of workflow 50 completed on fog_0 at time 32.32697833333339
# Task ID00091 of workflow 50 completed on iot_7 at time 32.32931833333339
# Task ID00096 of workflow 24 completed on iot_5 at time 32.335285833333394
# Task ID00092 of workflow 60 completed on iot_8 at time 32.3360608333334
# Task ID00093 of workflow 60 completed on fog_6 at time 32.3362358333334
# Task ID00097 of workflow 24 completed on iot_4 at time 32.33724583333339
# Task ID00096 of workflow 78 completed on iot_0 at time 32.3383658333334
# Task ID00097 of workflow 78 completed on server_1 at time 32.33852916666673
# Task ID00098 of workflow 78 completed on server_3 at time 32.34682416666673
# Task ID00099 of workflow 78 completed on server_0 at time 32.346995833333395
# Task ID00098 of workflow 24 completed on fog_7 at time 32.34968833333339
# Task ID00000 of workflow 78 completed on fog_7 at time 32.34977333333339
# Task ID00001 of workflow 78 completed on fog_5 at time 32.34997333333339
# Workflow 78 is completed! Total completed workflows: 90
# Task ID00099 of workflow 24 completed on iot_1 at time 32.35174833333339
# Task ID00000 of workflow 24 completed on iot_3 at time 32.35242833333339
# Task ID00001 of workflow 24 completed on iot_3 at time 32.354028333333396
# Workflow 24 is completed! Total completed workflows: 91
# Task ID00094 of workflow 4 completed on iot_8 at time 32.4330208333334
# Task ID00095 of workflow 4 completed on iot_1 at time 32.4345008333334
# Task ID00092 of workflow 50 completed on iot_7 at time 32.44099833333339
# Task ID00093 of workflow 50 completed on fog_5 at time 32.44117333333339
# Task ID00098 of workflow 14 completed on iot_8 at time 32.5325608333334
# Task ID00099 of workflow 14 completed on iot_2 at time 32.5346208333334
# Task ID00000 of workflow 14 completed on iot_9 at time 32.5353008333334
# Task ID00001 of workflow 14 completed on server_3 at time 32.53543416666673
# Workflow 14 is completed! Total completed workflows: 92
# Task ID00094 of workflow 50 completed on iot_0 at time 32.53813333333339
# Task ID00095 of workflow 50 completed on server_1 at time 32.538256666666726
# Task ID00096 of workflow 4 completed on iot_1 at time 32.5483008333334
# Task ID00097 of workflow 4 completed on iot_2 at time 32.5502608333334
# Task ID00096 of workflow 50 completed on fog_4 at time 32.55248166666673
# Task ID00097 of workflow 50 completed on server_1 at time 32.55264500000006
# Task ID00098 of workflow 50 completed on server_0 at time 32.56094000000006
# Task ID00099 of workflow 50 completed on fog_3 at time 32.561197500000056
# Task ID00000 of workflow 50 completed on iot_0 at time 32.56187750000006
# Task ID00001 of workflow 50 completed on fog_1 at time 32.56207750000006
# Workflow 50 is completed! Total completed workflows: 93
# Task ID00098 of workflow 34 completed on iot_8 at time 32.632100833333396
# Task ID00099 of workflow 34 completed on fog_4 at time 32.63235833333339
# Task ID00000 of workflow 34 completed on fog_7 at time 32.63244333333339
# Task ID00001 of workflow 34 completed on server_2 at time 32.63257666666672
# Workflow 34 is completed! Total completed workflows: 94
# Task ID00093 of workflow 40 completed on iot_8 at time 32.63350083333339
# Task ID00001 of workflow 19 completed on iot_8 at time 32.6351008333334
# Workflow 19 is completed! Total completed workflows: 95
# Task ID00094 of workflow 40 completed on fog_2 at time 32.645620833333396
# Task ID00095 of workflow 40 completed on iot_7 at time 32.6471008333334
# Task ID00098 of workflow 4 completed on iot_1 at time 32.649800833333394
# Task ID00099 of workflow 4 completed on iot_6 at time 32.651860833333394
# Task ID00000 of workflow 4 completed on fog_1 at time 32.65194583333339
# Task ID00001 of workflow 4 completed on fog_1 at time 32.65214583333339
# Workflow 4 is completed! Total completed workflows: 96
# Task ID00098 of workflow 93 completed on iot_8 at time 32.734640833333394
# Task ID00099 of workflow 93 completed on server_4 at time 32.73481250000006
# Task ID00000 of workflow 47 completed on iot_8 at time 32.7353208333334
# Task ID00000 of workflow 93 completed on iot_7 at time 32.73549250000006
# Task ID00001 of workflow 93 completed on iot_0 at time 32.73709250000007
# Workflow 93 is completed! Total completed workflows: 97
# Task ID00094 of workflow 60 completed on iot_8 at time 32.8322808333334
# Task ID00095 of workflow 60 completed on server_3 at time 32.832404166666734
# Task ID00096 of workflow 60 completed on server_2 at time 32.84188750000007
# Task ID00097 of workflow 60 completed on server_4 at time 32.8420508333334
# Task ID00098 of workflow 60 completed on iot_5 at time 32.9415908333334
# Task ID00099 of workflow 60 completed on server_4 at time 32.94176250000007
# Task ID00000 of workflow 60 completed on fog_0 at time 32.941847500000065
# Task ID00001 of workflow 60 completed on iot_1 at time 32.94344750000007
# Workflow 60 is completed! Total completed workflows: 98
# Task ID00096 of workflow 40 completed on iot_8 at time 32.9460808333334
# Task ID00097 of workflow 40 completed on server_4 at time 32.94624416666673
# Task ID00001 of workflow 47 completed on iot_8 at time 32.9476808333334
# Workflow 47 is completed! Total completed workflows: 99
# Task ID00098 of workflow 40 completed on fog_1 at time 32.95868666666673
# Task ID00099 of workflow 40 completed on iot_2 at time 32.96074666666673
# Task ID00000 of workflow 40 completed on fog_4 at time 32.96083166666673
# Task ID00001 of workflow 40 completed on fog_7 at time 32.96103166666673
# Workflow 40 is completed! Total completed workflows: 100
# 118.86730416666877
